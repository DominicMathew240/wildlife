# %%
# Install required packages
# !pip install -q timm
# !pip install -q pytorch-lightning
# !pip install -q torch>=2.0.0 torchvision>=0.15.0
# !pip install pytorch-lightning torchmetrics

import os
import json
import numpy as np
import pandas as pd
from pathlib import Path
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms
import pytorch_lightning as pl
import timm
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from datetime import datetime
import zipfile
import torchmetrics

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set up project directories
PROJECT_DIR = Path('/content/drive/MyDrive/SpeciesDetectionAI')
ZIP_PATH = PROJECT_DIR / 'dataset.zip'
DATA_DIR = PROJECT_DIR / 'dataset'
OUTPUT_DIR = PROJECT_DIR / 'outputs'
CHECKPOINT_DIR = OUTPUT_DIR / 'checkpoints'
LOGS_DIR = OUTPUT_DIR / 'logs'
ANALYSIS_DIR = OUTPUT_DIR / 'analysis'

# Create directories if they don't exist
for dir in [OUTPUT_DIR, CHECKPOINT_DIR, LOGS_DIR, ANALYSIS_DIR]:
    dir.mkdir(parents=True, exist_ok=True)

# Unzip dataset if needed
def setup_dataset():
    if not DATA_DIR.exists() and ZIP_PATH.exists():
        print("Unzipping dataset...")
        with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
            zip_ref.extractall(PROJECT_DIR)
        print("Dataset unzipped successfully")
    elif not DATA_DIR.exists():
        raise FileNotFoundError(f"Neither dataset directory nor zip file found at {DATA_DIR} or {ZIP_PATH}")

    # Verify the required files exist
    class_mappings_file = DATA_DIR / 'class_mappings.json'
    splits_dir = DATA_DIR / 'splits'

    if not class_mappings_file.exists():
        raise FileNotFoundError(f"class_mappings.json not found in {DATA_DIR}")
    if not splits_dir.exists():
        raise FileNotFoundError(f"splits directory not found in {DATA_DIR}")

    print("Dataset setup completed successfully")
    return class_mappings_file

class WildlifeDataset(Dataset):
    def __init__(self, root_dir, split='train', transform=None):
        self.root_dir = Path(root_dir)
        self.split = split
        self.transform = transform
        self.images = []
        self.labels = []

        # Load class mappings
        class_mappings_file = self.root_dir / 'class_mappings.json'
        print(f"Loading class mappings from: {class_mappings_file}")
        with open(class_mappings_file, 'r') as f:
            self.class_info = json.load(f)

        self.num_classes = len(self.class_info['species_list'])
        print(f"Number of classes: {self.num_classes}")

        # Look for splits directory
        splits_dir = self.root_dir / 'splits'
        if not splits_dir.is_dir():
            raise FileNotFoundError(f"Could not find splits directory in {self.root_dir}")

        split_dir = splits_dir / split
        if not split_dir.exists():
            if split == 'val':
                print("Validation directory not found, using a subset of training data for validation")
                split_dir = splits_dir / 'train'
                if not split_dir.exists():
                    raise FileNotFoundError("Could not find training split directory")
            else:
                raise FileNotFoundError(f"Could not find directory for {split} split")

        print(f"Using split directory: {split_dir}")

        # Load images for each species
        for species_name, class_id in self.class_info['species_to_idx'].items():
            species_dir = split_dir / species_name
            if not species_dir.exists():
                print(f"Warning: Directory not found for species {species_name}")
                continue

            # Try both 'images' subdirectory and direct image files
            image_paths = []
            image_dir = species_dir / 'images'
            if image_dir.exists():
                image_paths.extend(list(image_dir.glob('*.jpg')))
            image_paths.extend(list(species_dir.glob('*.jpg')))

            self.images.extend(image_paths)
            self.labels.extend([class_id] * len(image_paths))
            print(f"Found {len(image_paths)} images for species {species_name}")

        print(f"\nTotal images found for {split} split: {len(self.images)}")
        if len(self.images) == 0:
            raise ValueError(f"No valid images found in {split_dir}")

        # Calculate class weights for handling imbalance
        self.class_counts = np.bincount(self.labels)
        print("\nClass distribution:")
        for class_idx, count in enumerate(self.class_counts):
            species_name = next(name for name, idx in self.class_info['species_to_idx'].items() if idx == class_idx)
            print(f"{species_name}: {count} images")

        self.class_weights = 1. / torch.tensor(self.class_counts, dtype=torch.float)
        self.weights = self.class_weights[self.labels]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        # Load and transform image
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        return image, label

class WildlifeClassifier(pl.LightningModule):
    def __init__(self, num_classes, learning_rate=1e-4):
        super().__init__()
        self.save_hyperparameters()

        # Load EfficientNet-B2 model
        self.model = timm.create_model('tf_efficientnet_b2',
                                     pretrained=True,
                                     num_classes=num_classes)

        # Loss function with class weights
        self.criterion = nn.CrossEntropyLoss()

        # Updated metrics initialization using torchmetrics
        self.train_acc = torchmetrics.Accuracy(task='multiclass', num_classes=num_classes)
        self.val_acc = torchmetrics.Accuracy(task='multiclass', num_classes=num_classes)

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = self.criterion(logits, y)

        # Calculate accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.train_acc(preds, y)

        # Log metrics
        self.log('train_loss', loss, prog_bar=True)
        self.log('train_acc', acc, prog_bar=True)

        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = self.criterion(logits, y)

        # Calculate accuracy
        preds = torch.argmax(logits, dim=1)
        acc = self.val_acc(preds, y)

        # Log metrics
        self.log('val_loss', loss, prog_bar=True)
        self.log('val_acc', acc, prog_bar=True)

        return {'val_loss': loss, 'val_acc': acc}

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(
            self.parameters(),
            lr=self.hparams.learning_rate,
            weight_decay=0.0001
        )

        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.1,
            patience=3,
            verbose=True
        )

        return {
            'optimizer': optimizer,
            'lr_scheduler': {
                'scheduler': scheduler,
                'monitor': 'val_loss'
            }
        }

def main():
    # Setup dataset first
    try:
        setup_dataset()
    except Exception as e:
        print(f"Error setting up dataset: {str(e)}")
        return

    # Get current timestamp
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')

    # Data transforms
    train_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    val_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Create datasets
    train_dataset = WildlifeDataset(
        root_dir=DATA_DIR,
        split='train',
        transform=train_transform
    )

    # Setup weighted sampler for handling class imbalance
    sampler = WeightedRandomSampler(
        weights=train_dataset.weights,
        num_samples=len(train_dataset),
        replacement=True
    )

    # Create train loader with sampler
    train_loader = DataLoader(
        train_dataset,
        batch_size=32,
        sampler=sampler,
        num_workers=2,
        pin_memory=True
    )

    # Try to create validation dataset
    try:
        val_dataset = WildlifeDataset(
            root_dir=DATA_DIR,
            split='val',
            transform=val_transform
        )
    except FileNotFoundError:
        print("Using 20% of training data for validation")
        train_size = int(0.8 * len(train_dataset))
        val_size = len(train_dataset) - train_size
        train_dataset, val_dataset = torch.utils.data.random_split(
            train_dataset,
            [train_size, val_size]
        )

    val_loader = DataLoader(
        val_dataset,
        batch_size=32,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )

    # Initialize model
    model = WildlifeClassifier(
        num_classes=len(train_dataset.class_info['species_list']),
        learning_rate=1e-4
    )

    # Initialize trainer
    trainer = pl.Trainer(
        max_epochs=15,
        accelerator='gpu',
        devices=1,
        callbacks=[
            pl.callbacks.ModelCheckpoint(
                dirpath=str(CHECKPOINT_DIR),
                filename=f'efficientnet_b2_{timestamp}' + '-{epoch:02d}-{val_loss:.2f}',
                save_top_k=3,
                monitor='val_loss'
            ),
            pl.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=5,
                mode='min'
            )
        ],
        logger=pl.loggers.CSVLogger(save_dir=str(LOGS_DIR), name='wildlife_classification')
    )

    # Train model
    trainer.fit(model, train_loader, val_loader)

    # Save final model
    final_model_path = OUTPUT_DIR / f'final_model_{timestamp}.pth'
    torch.save(model.state_dict(), str(final_model_path))

    # Save model configuration
    config = {
        'num_classes': len(train_dataset.class_info['species_list']),
        'class_mapping': train_dataset.class_info['species_to_idx'],
        'image_size': (224, 224),
        'timestamp': timestamp
    }

    with open(OUTPUT_DIR / f'model_config_{timestamp}.json', 'w') as f:
        json.dump(config, f, indent=4)

if __name__ == '__main__':
    main()
# Out:
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.5.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.66.6)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (24.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (0.11.9)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.11.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (75.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch-lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.10)
# Mounted at /content/drive
# Unzipping dataset...
# Dataset unzipped successfully
# Dataset setup completed successfully
# Loading class mappings from: /content/drive/MyDrive/SpeciesDetectionAI/dataset/class_mappings.json
# Number of classes: 38
# Using split directory: /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/train
# Found 187 images for species banded civet
# Found 2 images for species banded linsang
# Found 5 images for species bay cat
# Found 316 images for species bearded pig
# Found 4 images for species binturong
# Found 4 images for species bird sp
# Found 102 images for species bulwer's pheasant
# Found 343 images for species great argus pheasant
# Found 3 images for species ground tufted squirrel
# Found 204 images for species human
# Found 105 images for species leopard cat
# Found 293 images for species long-tailed macaque
# Found 20 images for species long-tailed porcupine
# Found 220 images for species malayan civet
# Found 259 images for species malayan porcupine
# Found 5 images for species marbled cat
# Found 5 images for species masked palm civet
# Found 126 images for species mongoose sp
# Found 14 images for species monitor lizard
# Found 49 images for species mouse sp
# Found 204 images for species mousedeer sp
# Found 234 images for species muntjac sp
# Found 1 images for species otter civet
# Found 10 images for species pangolin
# Found 458 images for species pig-tailed macaque
# Found 2 images for species pigeon sp
# Found 76 images for species rat sp
# Found 2 images for species roughneck monitor lizard
# Found 59 images for species roulroul
# Found 404 images for species sambar deer
# Found 10 images for species small-toothed palm civet
# Found 17 images for species squirrel sp
# Found 312 images for species sun bear
# Found 237 images for species thick-spined porcupine
# Found 125 images for species treeshrew sp
# Found 1 images for species tufted squirrel
# Found 12 images for species white fronted langur
# Found 12 images for species yellow-throated marten
#
# Total images found for train split: 4442
#
# Class distribution:
# banded civet: 187 images
# banded linsang: 2 images
# bay cat: 5 images
# bearded pig: 316 images
# binturong: 4 images
# bird sp: 4 images
# bulwer's pheasant: 102 images
# great argus pheasant: 343 images
# ground tufted squirrel: 3 images
# human: 204 images
# leopard cat: 105 images
# long-tailed macaque: 293 images
# long-tailed porcupine: 20 images
# malayan civet: 220 images
# malayan porcupine: 259 images
# marbled cat: 5 images
# masked palm civet: 5 images
# mongoose sp: 126 images
# monitor lizard: 14 images
# mouse sp: 49 images
# mousedeer sp: 204 images
# muntjac sp: 234 images
# otter civet: 1 images
# pangolin: 10 images
# pig-tailed macaque: 458 images
# pigeon sp: 2 images
# rat sp: 76 images
# roughneck monitor lizard: 2 images
# roulroul: 59 images
# sambar deer: 404 images
# small-toothed palm civet: 10 images
# squirrel sp: 17 images
# sun bear: 312 images
# thick-spined porcupine: 237 images
# treeshrew sp: 125 images
# tufted squirrel: 1 images
# white fronted langur: 12 images
# yellow-throated marten: 12 images
# Loading class mappings from: /content/drive/MyDrive/SpeciesDetectionAI/dataset/class_mappings.json
# Number of classes: 38
# Using split directory: /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/val
# Found 37 images for species banded civet
# Found 1 images for species banded linsang
# Found 1 images for species bay cat
# Found 63 images for species bearded pig
# Found 1 images for species binturong
# Found 1 images for species bird sp
# Found 20 images for species bulwer's pheasant
# Found 68 images for species great argus pheasant
# Found 1 images for species ground tufted squirrel
# Found 40 images for species human
# Found 21 images for species leopard cat
# Found 58 images for species long-tailed macaque
# Found 4 images for species long-tailed porcupine
# Found 44 images for species malayan civet
# Found 51 images for species malayan porcupine
# Found 1 images for species marbled cat
# Found 1 images for species masked palm civet
# Found 25 images for species mongoose sp
# Found 2 images for species monitor lizard
# Found 9 images for species mouse sp
# Found 40 images for species mousedeer sp
# Found 46 images for species muntjac sp
# Found 1 images for species otter civet
# Found 2 images for species pangolin
# Found 91 images for species pig-tailed macaque
# Found 1 images for species pigeon sp
# Found 15 images for species rat sp
# Found 1 images for species roughneck monitor lizard
# Found 11 images for species roulroul
# Found 80 images for species sambar deer
# Found 2 images for species small-toothed palm civet
# Found 3 images for species squirrel sp
# Found 62 images for species sun bear
# Found 47 images for species thick-spined porcupine
# Found 25 images for species treeshrew sp
# Found 1 images for species tufted squirrel
# Found 2 images for species white fronted langur
# Found 2 images for species yellow-throated marten
#
# Total images found for val split: 881
#
# Class distribution:
# banded civet: 37 images
# banded linsang: 1 images
# bay cat: 1 images
# bearded pig: 63 images
# binturong: 1 images
# bird sp: 1 images
# bulwer's pheasant: 20 images
# great argus pheasant: 68 images
# ground tufted squirrel: 1 images
# human: 40 images
# leopard cat: 21 images
# long-tailed macaque: 58 images
# long-tailed porcupine: 4 images
# malayan civet: 44 images
# malayan porcupine: 51 images
# marbled cat: 1 images
# masked palm civet: 1 images
# mongoose sp: 25 images
# monitor lizard: 2 images
# mouse sp: 9 images
# mousedeer sp: 40 images
# muntjac sp: 46 images
# otter civet: 1 images
# pangolin: 2 images
# pig-tailed macaque: 91 images
# pigeon sp: 1 images
# rat sp: 15 images
# roughneck monitor lizard: 1 images
# roulroul: 11 images
# sambar deer: 80 images
# small-toothed palm civet: 2 images
# squirrel sp: 3 images
# sun bear: 62 images
# thick-spined porcupine: 47 images
# treeshrew sp: 25 images
# tufted squirrel: 1 images
# white fronted langur: 2 images
# yellow-throated marten: 2 images
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/36.8M [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | EfficientNet       | 7.8 M  | train
# 1 | criterion | CrossEntropyLoss   | 0      | train
# 2 | train_acc | MulticlassAccuracy | 0      | train
# 3 | val_acc   | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 7.8 M     Trainable params
# 0         Non-trainable params
# 7.8 M     Total params
# 31.018    Total estimated model params size (MB)
# 476       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=15` reached.

# %%
# !pip install -q timm seaborn scikit-learn tqdm

# %%
# !pip install -q timm seaborn scikit-learn tqdm

import torch
import timm
import json
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, roc_curve, auc
from tqdm.notebook import tqdm
import zipfile
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set up project directories
PROJECT_DIR = Path('/content/drive/MyDrive/SpeciesDetectionAI')
MODEL_PATH = PROJECT_DIR / 'outputs' / 'final_model_20241125_041231.pth'
CONFIG_PATH = PROJECT_DIR / 'outputs' / 'model_config_20241125_041231.json'
ZIP_PATH = PROJECT_DIR / 'dataset.zip'
DATA_DIR = PROJECT_DIR / 'dataset'
OUTPUT_DIR = PROJECT_DIR / 'outputs'
ANALYSIS_DIR = OUTPUT_DIR / 'analysis'

# Create directories
print("Creating directories...")
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)
ANALYSIS_DIR.mkdir(exist_ok=True, parents=True)

# Verify paths
print("\nVerifying paths...")
print(f"Model exists: {MODEL_PATH.exists()}")
print(f"Config exists: {CONFIG_PATH.exists()}")
print(f"Dataset zip exists: {ZIP_PATH.exists()}")

# Load model config first
print("\nLoading model configuration...")
with open(CONFIG_PATH, 'r') as f:
    model_config = json.load(f)
    print("Model config loaded successfully")

class WildlifeDataset(Dataset):
    def __init__(self, root_dir, split='train', transform=None):
        self.root_dir = Path(root_dir)
        self.split = split
        self.transform = transform
        self.images = []
        self.labels = []

        # Load class mappings
        with open(CONFIG_PATH, 'r') as f:
            self.class_info = json.load(f)

        self.num_classes = len(self.class_info['class_mapping'])
        print(f"Number of classes: {self.num_classes}")

        # Look for splits directory
        splits_dir = self.root_dir / 'splits'
        split_dir = splits_dir / split

        if not split_dir.exists():
            # Try looking in the root of the dataset directory
            split_dir = self.root_dir / split
            if not split_dir.exists():
                raise FileNotFoundError(f"Could not find directory for {split} split")

        print(f"Using split directory: {split_dir}")

        # Load images for each species
        for species_name, class_id in self.class_info['class_mapping'].items():
            species_dir = split_dir / species_name
            if not species_dir.exists():
                print(f"Warning: Directory not found for species {species_name}")
                continue

            # Try both 'images' subdirectory and direct image files
            image_paths = []
            image_dir = species_dir / 'images'
            if image_dir.exists():
                image_paths.extend(list(image_dir.glob('*.jpg')))
            image_paths.extend(list(species_dir.glob('*.jpg')))

            self.images.extend(image_paths)
            self.labels.extend([class_id] * len(image_paths))

        print(f"Total images found for {split} split: {len(self.images)}")
        if len(self.images) == 0:
            raise ValueError(f"No valid images found in {split_dir}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        # Load and transform image
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        return image, label

def unzip_dataset():
    if not DATA_DIR.exists() and ZIP_PATH.exists():
        print("\nUnzipping dataset...")
        with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
            zip_ref.extractall(PROJECT_DIR)
        print("Dataset unzipped successfully")
    elif not DATA_DIR.exists():
        raise FileNotFoundError(f"Neither dataset directory nor zip file found")
    else:
        print("\nDataset directory already exists")

# Unzip dataset if needed
unzip_dataset()

# Initialize model
print("\nInitializing model...")
model = timm.create_model('tf_efficientnet_b2', pretrained=False, num_classes=model_config['num_classes'])
state_dict = torch.load(MODEL_PATH, map_location='cuda' if torch.cuda.is_available() else 'cpu')
# Remove 'model.' prefix if present
state_dict = {k.replace('model.', ''): v for k, v in state_dict.items()}
model.load_state_dict(state_dict)
model.eval()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
print(f"Model loaded and moved to {device}")

# Setup transforms
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load test data
print("\nLoading test dataset...")
test_dataset = WildlifeDataset(DATA_DIR, split='test', transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)
print(f"Test dataset loaded with {len(test_dataset)} images")

# Collect predictions and ground truth
print("\nRunning predictions...")
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in tqdm(test_loader, desc="Evaluating"):
        images = images.to(device)
        outputs = model(images)
        probabilities = torch.softmax(outputs, dim=1)
        _, predictions = torch.max(outputs, 1)

        all_probs.extend(probabilities.cpu().numpy())
        all_preds.extend(predictions.cpu().numpy())
        all_labels.extend(labels.numpy())

all_probs = np.array(all_probs)
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Get class names
idx_to_class = {v: k for k, v in model_config['class_mapping'].items()}
class_names = [idx_to_class[i] for i in range(len(idx_to_class))]

print("\nGenerating visualizations...")

# 1. Confusion Matrix
plt.figure(figsize=(15, 15))
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=45)
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.close()

# 2. Per-class Accuracy Bar Plot
plt.figure(figsize=(15, 6))
class_accuracy = cm.diagonal() / cm.sum(axis=1)
sns.barplot(x=class_names, y=class_accuracy)
plt.title('Per-class Accuracy')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Accuracy')
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'per_class_accuracy.png', dpi=300, bbox_inches='tight')
plt.close()

# 3. ROC Curves
plt.figure(figsize=(12, 8))
for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(all_labels == i, all_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_names[i][:10]}... (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'roc_curves.png', dpi=300, bbox_inches='tight')
plt.close()

# 4. Precision-Recall Curves
plt.figure(figsize=(12, 8))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(all_labels == i, all_probs[:, i])
    plt.plot(recall, precision, label=f'{class_names[i][:10]}...')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'precision_recall_curves.png', dpi=300, bbox_inches='tight')
plt.close()

# 5. Generate Classification Report
report = classification_report(all_labels, all_preds, target_names=class_names)
print("\nClassification Report:")
print(report)

# Save classification report
with open(ANALYSIS_DIR / 'classification_report.txt', 'w') as f:
    f.write(report)

# 6. Top Misclassifications Analysis
misclassified = []
for pred, true, prob in zip(all_preds, all_labels, all_probs):
    if pred != true:
        misclassified.append({
            'true': idx_to_class[true],
            'predicted': idx_to_class[pred],
            'confidence': prob[pred]
        })

if misclassified:
    misclassified.sort(key=lambda x: x['confidence'], reverse=True)

    # Plot top misclassifications
    plt.figure(figsize=(12, 6))
    top_n = min(10, len(misclassified))
    top_misclassified = misclassified[:top_n]

    plt.bar(
        range(top_n),
        [x['confidence'] for x in top_misclassified],
        tick_label=[f"{x['true'][:10]}...\n→\n{x['predicted'][:10]}..." for x in top_misclassified]
    )
    plt.title('Top Misclassifications with Confidence')
    plt.ylabel('Confidence')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(ANALYSIS_DIR / 'top_misclassifications.png', dpi=300, bbox_inches='tight')
plt.close()

# Calculate and save overall metrics
accuracy = (all_preds == all_labels).mean()
print(f"\nOverall Test Accuracy: {accuracy:.4f}")

test_metrics = {
    'overall_accuracy': float(accuracy),
    'per_class_accuracy': {class_names[i]: float(class_accuracy[i]) for i in range(len(class_names))},
    'number_of_test_samples': len(test_dataset),
    'number_of_classes': len(class_names)
}

with open(ANALYSIS_DIR / 'test_metrics.json', 'w') as f:
    json.dump(test_metrics, f, indent=4)

print(f"\nAll visualizations have been saved to {ANALYSIS_DIR}")
# Out:
# Mounted at /content/drive
# Creating directories...
#
# Verifying paths...
# Model exists: True
# Config exists: True
# Dataset zip exists: True
#
# Loading model configuration...
# Model config loaded successfully
#
# Dataset directory already exists
#
# Initializing model...
# <ipython-input-4-a3137fc3b221>:125: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(MODEL_PATH, map_location='cuda' if torch.cuda.is_available() else 'cpu')
# Model loaded and moved to cuda
#
# Loading test dataset...
# Number of classes: 38
# Using split directory: /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test
# Warning: Directory not found for species ground tufted squirrel
# Warning: Directory not found for species tufted squirrel
# Total images found for test split: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a3137fc3b221> in <cell line: 143>()
#     141 # Load test data
#     142 print("\nLoading test dataset...")
# --> 143 test_dataset = WildlifeDataset(DATA_DIR, split='test', transform=test_transform)
#     144 test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)
#     145 print(f"Test dataset loaded with {len(test_dataset)} images")
#
# <ipython-input-4-a3137fc3b221> in __init__(self, root_dir, split, transform)
#      90         print(f"Total images found for {split} split: {len(self.images)}")
#      91         if len(self.images) == 0:
# ---> 92             raise ValueError(f"No valid images found in {split_dir}")
#      93
#      94     def __len__(self):
#
# ValueError: No valid images found in /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test

# %%
# First, let's check the actual structure of the test folder
import os

def print_directory_structure(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * level
        print(f'{indent}{os.path.basename(root)}/')
        subindent = ' ' * 4 * (level + 1)
        for f in files[:5]:  # Print first 5 files in each directory
            print(f'{subindent}{f}')
        if len(files) > 5:
            print(f'{subindent}... and {len(files)-5} more files')

print("Checking dataset structure:")
print("\nMain dataset directory structure:")
print_directory_structure(str(DATA_DIR))

# Now let's modify the WildlifeDataset class to be more flexible
class WildlifeDataset(Dataset):
    def __init__(self, root_dir, split='train', transform=None):
        self.root_dir = Path(root_dir)
        self.split = split
        self.transform = transform
        self.images = []
        self.labels = []

        # Load class mappings
        with open(CONFIG_PATH, 'r') as f:
            self.class_info = json.load(f)

        self.num_classes = len(self.class_info['class_mapping'])
        print(f"Number of classes: {self.num_classes}")

        # Try different possible test directory locations
        possible_paths = [
            self.root_dir / 'splits' / split,
            self.root_dir / split,
            self.root_dir / 'test',
            self.root_dir
        ]

        split_dir = None
        for path in possible_paths:
            if path.exists():
                print(f"Found potential split directory: {path}")
                # Verify it contains image data
                if any(path.glob('**/*.jpg')) or any(path.glob('**/*.jpeg')) or any(path.glob('**/*.png')):
                    split_dir = path
                    break

        if split_dir is None:
            raise FileNotFoundError(f"Could not find valid directory for {split} split")

        print(f"Using split directory: {split_dir}")

        # Load images using different possible directory structures
        for species_name, class_id in self.class_info['class_mapping'].items():
            # Try different possible paths for each species
            possible_species_paths = [
                split_dir / species_name,
                split_dir / 'images' / species_name,
                split_dir / species_name / 'images',
            ]

            images_found = False
            for species_dir in possible_species_paths:
                if species_dir.exists():
                    print(f"Found directory for species {species_name} at {species_dir}")
                    # Look for images in this directory and all subdirectories
                    image_paths = []
                    for ext in ['.jpg', '.jpeg', '.png']:
                        image_paths.extend(list(species_dir.glob(f'**/*{ext}')))

                    if image_paths:
                        self.images.extend(image_paths)
                        self.labels.extend([class_id] * len(image_paths))
                        print(f"Found {len(image_paths)} images for species {species_name}")
                        images_found = True
                        break

            if not images_found:
                print(f"Warning: No images found for species {species_name}")

        print(f"\nTotal images found for {split} split: {len(self.images)}")
        if len(self.images) == 0:
            raise ValueError(f"No valid images found in any of the searched directories")

        # Print some sample paths to verify
        print("\nSample image paths:")
        for path in self.images[:5]:
            print(path)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        # Load and transform image
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        return image, label

# Now let's try to load the test dataset
print("\nAttempting to load test dataset...")

try:
    test_dataset = WildlifeDataset(DATA_DIR, split='test', transform=test_transform)
    print("\nSuccess! Found test dataset.")
    print(f"Number of test images: {len(test_dataset)}")
except Exception as e:
    print(f"\nError loading test dataset: {str(e)}")
    print("\nPlease verify the correct location of your test images and their organization.")
# Out:
# Checking dataset structure:
#
# Main dataset directory structure:
# dataset/
#     class_mappings.json
#     split_statistics.json
#     config/
#     splits/
#         test/
#             banded civet/
#                 images/
#                     banded_civet_104.JPG
#                     banded_civet_105.JPG
#                     banded_civet_106.JPG
#                     banded_civet_119.JPG
#                     banded_civet_12.JPG
#                     ... and 21 more files
#                 labels/
#             banded linsang/
#                 images/
#                 labels/
#             bay cat/
#                 images/
#                 labels/
#             bearded pig/
#                 images/
#                     bearded_pig_100.JPG
#                     bearded_pig_1005.JPG
#                     bearded_pig_101.JPG
#                     bearded_pig_1021.JPG
#                     bearded_pig_1024.JPG
#                     ... and 248 more files
#                 labels/
#             binturong/
#                 images/
#                 labels/
#             bird sp/
#                 images/
#                 labels/
#             bulwer's pheasant/
#                 images/
#                     bulwer's_pheasant_104.JPG
#                     bulwer's_pheasant_105.JPG
#                     bulwer's_pheasant_106.JPG
#                     bulwer's_pheasant_119.JPG
#                     bulwer's_pheasant_12.JPG
#                     ... and 16 more files
#                 labels/
#             great argus pheasant/
#                 images/
#                     great_argus_pheasant_11864.JPG
#                     great_argus_pheasant_11875.JPG
#                     great_argus_pheasant_11878.JPG
#                     great_argus_pheasant_11880.JPG
#                     great_argus_pheasant_11891.JPG
#                     ... and 1203 more files
#                 labels/
#             human/
#                 images/
#                     human_101.JPG
#                     human_11.JPG
#                     human_110.JPG
#                     human_112.JPG
#                     human_113.JPG
#                     ... and 26 more files
#                 labels/
#             leopard cat/
#                 images/
#                     leopard_cat_104.JPG
#                     leopard_cat_105.JPG
#                     leopard_cat_106.JPG
#                     leopard_cat_119.JPG
#                     leopard_cat_12.JPG
#                     ... and 10 more files
#                 labels/
#             long-tailed macaque/
#                 images/
#                     long-tailed_macaque_101.JPG
#                     long-tailed_macaque_11.JPG
#                     long-tailed_macaque_110.JPG
#                     long-tailed_macaque_112.JPG
#                     long-tailed_macaque_113.JPG
#                     ... and 38 more files
#                 labels/
#             long-tailed porcupine/
#                 images/
#                     long-tailed_porcupine_4.JPG
#                 labels/
#             malayan civet/
#                 images/
#                     malayan_civet_101.JPG
#                     malayan_civet_11.JPG
#                     malayan_civet_110.JPG
#                     malayan_civet_112.JPG
#                     malayan_civet_113.JPG
#                     ... and 46 more files
#                 labels/
#             malayan porcupine/
#                 images/
#                     malayan_porcupine_101.JPG
#                     malayan_porcupine_11.JPG
#                     malayan_porcupine_110.JPG
#                     malayan_porcupine_112.JPG
#                     malayan_porcupine_113.JPG
#                     ... and 33 more files
#                 labels/
#             marbled cat/
#                 images/
#                 labels/
#             masked palm civet/
#                 images/
#                 labels/
#             mongoose sp/
#                 images/
#                     mongoose_sp_104.JPG
#                     mongoose_sp_105.JPG
#                     mongoose_sp_106.JPG
#                     mongoose_sp_119.JPG
#                     mongoose_sp_12.JPG
#                     ... and 13 more files
#                 labels/
#             monitor lizard/
#                 images/
#                     monitor_lizard_12.JPG
#                 labels/
#             mouse sp/
#                 images/
#                     mouse_sp_22.JPG
#                 labels/
#             mousedeer sp/
#                 images/
#                     mousedeer_sp_101.JPG
#                     mousedeer_sp_11.JPG
#                     mousedeer_sp_110.JPG
#                     mousedeer_sp_112.JPG
#                     mousedeer_sp_113.JPG
#                     ... and 45 more files
#                 labels/
#             muntjac sp/
#                 images/
#                     muntjac_sp_101.JPG
#                     muntjac_sp_119.JPG
#                     muntjac_sp_120.JPG
#                     muntjac_sp_123.JPG
#                     muntjac_sp_125.JPG
#                     ... and 61 more files
#                 labels/
#             otter civet/
#                 images/
#                 labels/
#             pangolin/
#                 images/
#                     pangolin_6.JPG
#                 labels/
#             pig-tailed macaque/
#                 images/
#                     pig-tailed_macaque_100.JPG
#                     pig-tailed_macaque_1005.JPG
#                     pig-tailed_macaque_101.JPG
#                     pig-tailed_macaque_1021.JPG
#                     pig-tailed_macaque_1024.JPG
#                     ... and 240 more files
#                 labels/
#             pigeon sp/
#                 images/
#                 labels/
#             porcupine sp/
#                 images/
#                     porcupine_sp_5.JPG
#                 labels/
#             rat sp/
#                 images/
#                     rat_sp_101.JPG
#                     rat_sp_110.JPG
#                     rat_sp_111.JPG
#                     rat_sp_114.JPG
#                     rat_sp_19.JPG
#                     ... and 8 more files
#                 labels/
#             roughneck monitor lizard/
#                 images/
#                 labels/
#             roulroul/
#                 images/
#                     roulroul_22.JPG
#                 labels/
#             sambar deer/
#                 images/
#                     sambar_deer_10.JPG
#                     sambar_deer_1003.JPG
#                     sambar_deer_1019.JPG
#                     sambar_deer_1021.JPG
#                     sambar_deer_1033.JPG
#                     ... and 205 more files
#                 labels/
#             small-toothed palm civet/
#                 images/
#                     small-toothed_palm_civet_8.JPG
#                 labels/
#             squirrel sp/
#                 images/
#                     squirrel_sp_11.JPG
#                 labels/
#             sun bear/
#                 images/
#                     sunbear_15.JPG
#                     sun_bear_105.JPG
#                     sun_bear_107.JPG
#                     sun_bear_11.JPG
#                     sun_bear_111.JPG
#                     ... and 71 more files
#                 labels/
#             thick-spined porcupine/
#                 images/
#                     thick-spined_porcupine_101.JPG
#                     thick-spined_porcupine_11.JPG
#                     thick-spined_porcupine_110.JPG
#                     thick-spined_porcupine_112.JPG
#                     thick-spined_porcupine_113.JPG
#                     ... and 35 more files
#                 labels/
#             treeshrew sp/
#                 images/
#                     treeshrew_sp_104.JPG
#                     treeshrew_sp_105.JPG
#                     treeshrew_sp_106.JPG
#                     treeshrew_sp_119.JPG
#                     treeshrew_sp_12.JPG
#                     ... and 16 more files
#                 labels/
#             white fronted langur/
#                 images/
#                     white_fronted_langur_12.JPG
#                 labels/
#             yellow-throated marten/
#                 images/
#                     yellow-throated_marten_12.JPG
#                 labels/
#         train/
#             banded civet/
#                 labels.cache
#                 images/
#                     banded_civet_100_JPG.rf.d66f6d36b5296054f96c800355889ae4.jpg
#                     banded_civet_101_JPG.rf.bd59def1a0a803cb24f10e50352297c2.jpg
#                     banded_civet_102_JPG.rf.663bc22f3df36469bbd789b7ff27ddbd.jpg
#                     banded_civet_103_JPG.rf.e3cf6cf37d1828b7f8005cbe04e029bb.jpg
#                     banded_civet_107_JPG.rf.2b69987be3f7f81656876989e0cc2da3.jpg
#                     ... and 182 more files
#                 labels/
#                     banded_civet_100_JPG.rf.d66f6d36b5296054f96c800355889ae4.txt
#                     banded_civet_101_JPG.rf.bd59def1a0a803cb24f10e50352297c2.txt
#                     banded_civet_102_JPG.rf.663bc22f3df36469bbd789b7ff27ddbd.txt
#                     banded_civet_103_JPG.rf.e3cf6cf37d1828b7f8005cbe04e029bb.txt
#                     banded_civet_107_JPG.rf.2b69987be3f7f81656876989e0cc2da3.txt
#                     ... and 182 more files
#             banded linsang/
#                 images/
#                     banded_linsang_1_JPG.rf.68761114b309fb82e7c64bc4ec48ea81.jpg
#                     banded_linsang_2_JPG.rf.11b4fead43b779ecd17e8b54f8b82741.jpg
#                 labels/
#                     banded_linsang_1_JPG.rf.68761114b309fb82e7c64bc4ec48ea81.txt
#                     banded_linsang_2_JPG.rf.11b4fead43b779ecd17e8b54f8b82741.txt
#             bay cat/
#                 images/
#                     bay_cat_1_JPG.rf.e2eed92a76dfb88b628e1d880381faf0.jpg
#                     bay_cat_2_JPG.rf.518b0eb48c62cf89ba7b39c955fc1ae3.jpg
#                     bay_cat_3_JPG.rf.ae4da7c620f25a635fc9c45b5d3dd6e0.jpg
#                     bay_cat_4_JPG.rf.c56261eeeeeda243e740e4e99035ff87.jpg
#                     bay_cat_5_JPG.rf.06910c7575db0bfd266e05decc6e1abe.jpg
#                 labels/
#                     bay_cat_1_JPG.rf.e2eed92a76dfb88b628e1d880381faf0.txt
#                     bay_cat_2_JPG.rf.518b0eb48c62cf89ba7b39c955fc1ae3.txt
#                     bay_cat_3_JPG.rf.ae4da7c620f25a635fc9c45b5d3dd6e0.txt
#                     bay_cat_4_JPG.rf.c56261eeeeeda243e740e4e99035ff87.txt
#                     bay_cat_5_JPG.rf.06910c7575db0bfd266e05decc6e1abe.txt
#             bearded pig/
#                 images/
#                     bearded_pig_102_JPG.rf.f882cc53ce5dba1cc95c27bdf21b64f9.jpg
#                     bearded_pig_103_JPG.rf.eca1a1592ad3c9e2cfa0e01f73dae00c.jpg
#                     bearded_pig_104_JPG.rf.c511ab6c36a2c31bf32e0be60ecded62.jpg
#                     bearded_pig_105_JPG.rf.c9ef9f92fb21c2b9e2cd419b2ff2f26a.jpg
#                     bearded_pig_106_JPG.rf.92245adb0b9d32ad927302ee3049783a.jpg
#                     ... and 311 more files
#                 labels/
#                     bearded_pig_102_JPG.rf.f882cc53ce5dba1cc95c27bdf21b64f9.txt
#                     bearded_pig_103_JPG.rf.eca1a1592ad3c9e2cfa0e01f73dae00c.txt
#                     bearded_pig_104_JPG.rf.c511ab6c36a2c31bf32e0be60ecded62.txt
#                     bearded_pig_105_JPG.rf.c9ef9f92fb21c2b9e2cd419b2ff2f26a.txt
#                     bearded_pig_106_JPG.rf.92245adb0b9d32ad927302ee3049783a.txt
#                     ... and 311 more files
#             binturong/
#                 images/
#                     binturong_1_JPG.rf.50e29e9b17f31fefabbcbfd36ffe7e0b.jpg
#                     binturong_2_JPG.rf.09e26779e6bf5fca3338e8809eb58162.jpg
#                     binturong_5_JPG.rf.db2c3a283dbd2017fca8e07f459fdf7b.jpg
#                     binturong_7_JPG.rf.f5c3ea3b5c5728afdde86ee5b6c5bd69.jpg
#                 labels/
#                     binturong_1_JPG.rf.50e29e9b17f31fefabbcbfd36ffe7e0b.txt
#                     binturong_2_JPG.rf.09e26779e6bf5fca3338e8809eb58162.txt
#                     binturong_5_JPG.rf.db2c3a283dbd2017fca8e07f459fdf7b.txt
#                     binturong_7_JPG.rf.f5c3ea3b5c5728afdde86ee5b6c5bd69.txt
#             bird sp/
#                 images/
#                     bird_sp_1_JPG.rf.d36c890225abc337183037ef2608307d.jpg
#                     bird_sp_2_JPG.rf.f734488a385468ebeaf76d39223c4c28.jpg
#                     bird_sp_3_JPG.rf.fdbffb65901ec75c29af8c4d15edc633.jpg
#                     bird_sp_7_JPG.rf.4ad4d20cdf86c45b68d62c092212491a.jpg
#                 labels/
#                     bird_sp_1_JPG.rf.d36c890225abc337183037ef2608307d.txt
#                     bird_sp_2_JPG.rf.f734488a385468ebeaf76d39223c4c28.txt
#                     bird_sp_3_JPG.rf.fdbffb65901ec75c29af8c4d15edc633.txt
#                     bird_sp_7_JPG.rf.4ad4d20cdf86c45b68d62c092212491a.txt
#             bulwer's pheasant/
#                 images/
#                     bulwer-s_pheasant_100_JPG.rf.b7ab64cacb9a1100b8ce4554a1945c6f.jpg
#                     bulwer-s_pheasant_101_JPG.rf.24112dc53b4529da3f515c730c55874a.jpg
#                     bulwer-s_pheasant_102_JPG.rf.0ab7be53ac43684d8d41210cd680f6d1.jpg
#                     bulwer-s_pheasant_103_JPG.rf.dfbfb2561f85d3f6cdf9e5ea59dac557.jpg
#                     bulwer-s_pheasant_107_JPG.rf.4b66e0d879a10419f7f96194957160ef.jpg
#                     ... and 97 more files
#                 labels/
#                     bulwer-s_pheasant_100_JPG.rf.b7ab64cacb9a1100b8ce4554a1945c6f.txt
#                     bulwer-s_pheasant_101_JPG.rf.24112dc53b4529da3f515c730c55874a.txt
#                     bulwer-s_pheasant_102_JPG.rf.0ab7be53ac43684d8d41210cd680f6d1.txt
#                     bulwer-s_pheasant_103_JPG.rf.dfbfb2561f85d3f6cdf9e5ea59dac557.txt
#                     bulwer-s_pheasant_107_JPG.rf.4b66e0d879a10419f7f96194957160ef.txt
#                     ... and 97 more files
#             great argus pheasant/
#                 images/
#                     great_argus_pheasant_103_JPG.rf.01ab4a329c5459bf910d54df6a062390.jpg
#                     great_argus_pheasant_10_JPG.rf.2cccb0a90ffcf01eaf8c44825bd9ef1b.jpg
#                     great_argus_pheasant_11_JPG.rf.826a5477be7d97ddf92717bfa7aa3b71.jpg
#                     great_argus_pheasant_12023_JPG.rf.df0635c9304683632f97a18354c4877a.jpg
#                     great_argus_pheasant_12028_JPG.rf.663ea6253375c741d593b19a6ebf3e49.jpg
#                     ... and 338 more files
#                 labels/
#                     great_argus_pheasant_103_JPG.rf.01ab4a329c5459bf910d54df6a062390.txt
#                     great_argus_pheasant_10_JPG.rf.2cccb0a90ffcf01eaf8c44825bd9ef1b.txt
#                     great_argus_pheasant_11_JPG.rf.826a5477be7d97ddf92717bfa7aa3b71.txt
#                     great_argus_pheasant_12023_JPG.rf.df0635c9304683632f97a18354c4877a.txt
#                     great_argus_pheasant_12028_JPG.rf.663ea6253375c741d593b19a6ebf3e49.txt
#                     ... and 338 more files
#             ground tufted squirrel/
#                 images/
#                     ground_tufted_squirrel_1_JPG.rf.9142e11099312db020508e9dcc95d789.jpg
#                     ground_tufted_squirrel_3_JPG.rf.b8cb6c3b986aa08fd233e9c9f2134a4c.jpg
#                     ground_tufted_squirrel_4_JPG.rf.27ceccfa1be806f6780906ae48b40446.jpg
#                 labels/
#                     ground_tufted_squirrel_1_JPG.rf.9142e11099312db020508e9dcc95d789.txt
#                     ground_tufted_squirrel_3_JPG.rf.b8cb6c3b986aa08fd233e9c9f2134a4c.txt
#                     ground_tufted_squirrel_4_JPG.rf.27ceccfa1be806f6780906ae48b40446.txt
#             human/
#                 images/
#                     human_100_JPG.rf.0f11472532ba0aec0f2433e9001dcba4.jpg
#                     human_102_JPG.rf.21b650a7740fc49361cce592c35e4590.jpg
#                     human_103_JPG.rf.e032f7baf4f5cc6a857bf2178e4b4bb7.jpg
#                     human_104_JPG.rf.adc39a3ce044f91193bb79ec219262d9.jpg
#                     human_105_JPG.rf.712206509fc3be9f09bd42c133f8f50d.jpg
#                     ... and 199 more files
#                 labels/
#                     human_100_JPG.rf.0f11472532ba0aec0f2433e9001dcba4.txt
#                     human_102_JPG.rf.21b650a7740fc49361cce592c35e4590.txt
#                     human_103_JPG.rf.e032f7baf4f5cc6a857bf2178e4b4bb7.txt
#                     human_104_JPG.rf.adc39a3ce044f91193bb79ec219262d9.txt
#                     human_105_JPG.rf.712206509fc3be9f09bd42c133f8f50d.txt
#                     ... and 199 more files
#             leopard cat/
#                 images/
#                     leopard_cat_100_JPG.rf.06e0ca8fa42c4ba01962b0a8267f3e44.jpg
#                     leopard_cat_101_JPG.rf.9574edc44f579d72f42087826bee0480.jpg
#                     leopard_cat_102_JPG.rf.ec7dc66831f2b51c058397d27d01bda3.jpg
#                     leopard_cat_103_JPG.rf.2df5fcf547a90baa07caa9841c4b2793.jpg
#                     leopard_cat_107_JPG.rf.e787e1725399dbe112c14adf06ba19b3.jpg
#                     ... and 100 more files
#                 labels/
#                     leopard_cat_100_JPG.rf.06e0ca8fa42c4ba01962b0a8267f3e44.txt
#                     leopard_cat_101_JPG.rf.9574edc44f579d72f42087826bee0480.txt
#                     leopard_cat_102_JPG.rf.ec7dc66831f2b51c058397d27d01bda3.txt
#                     leopard_cat_103_JPG.rf.2df5fcf547a90baa07caa9841c4b2793.txt
#                     leopard_cat_107_JPG.rf.e787e1725399dbe112c14adf06ba19b3.txt
#                     ... and 100 more files
#             long-tailed macaque/
#                 images/
#                     long-tailed_macaque_100_JPG.rf.a57e188a0567fb50c7dfed0c78b4e307.jpg
#                     long-tailed_macaque_102_JPG.rf.be72b8e474b4a9bc5cd07a17fd4e2d2f.jpg
#                     long-tailed_macaque_103_JPG.rf.68e186d24bb3e6f8df15d55e2bb58b59.jpg
#                     long-tailed_macaque_104_JPG.rf.5636cbf354769079a08572c111915f5e.jpg
#                     long-tailed_macaque_105_JPG.rf.286f3be431448bdab44b48a2bf00df52.jpg
#                     ... and 288 more files
#                 labels/
#                     long-tailed_macaque_100_JPG.rf.a57e188a0567fb50c7dfed0c78b4e307.txt
#                     long-tailed_macaque_102_JPG.rf.be72b8e474b4a9bc5cd07a17fd4e2d2f.txt
#                     long-tailed_macaque_103_JPG.rf.68e186d24bb3e6f8df15d55e2bb58b59.txt
#                     long-tailed_macaque_104_JPG.rf.5636cbf354769079a08572c111915f5e.txt
#                     long-tailed_macaque_105_JPG.rf.286f3be431448bdab44b48a2bf00df52.txt
#                     ... and 288 more files
#             long-tailed porcupine/
#                 images/
#                     long-tailed_porcupine_10_JPG.rf.7ea5c0ea085806d8cc0737cd248417a6.jpg
#                     long-tailed_porcupine_13_JPG.rf.abcd5306f0e6a9b0d6c6b01734535dbc.jpg
#                     long-tailed_porcupine_14_JPG.rf.b013efb8ed6ffd4c769cd2af1727ca88.jpg
#                     long-tailed_porcupine_15_JPG.rf.0b168678c55943e91c8d7606000a31c2.jpg
#                     long-tailed_porcupine_16_JPG.rf.9c707842f99ae74abd7edf9be21b4c0c.jpg
#                     ... and 15 more files
#                 labels/
#                     long-tailed_porcupine_10_JPG.rf.7ea5c0ea085806d8cc0737cd248417a6.txt
#                     long-tailed_porcupine_13_JPG.rf.abcd5306f0e6a9b0d6c6b01734535dbc.txt
#                     long-tailed_porcupine_14_JPG.rf.b013efb8ed6ffd4c769cd2af1727ca88.txt
#                     long-tailed_porcupine_15_JPG.rf.0b168678c55943e91c8d7606000a31c2.txt
#                     long-tailed_porcupine_16_JPG.rf.9c707842f99ae74abd7edf9be21b4c0c.txt
#                     ... and 15 more files
#             malayan civet/
#                 images/
#                     malayan_civet_100_JPG.rf.461cc946f446e54ac0a9da6f457d1a1c.jpg
#                     malayan_civet_102_JPG.rf.79b6d3660ac8f8df7a59ea26d29dbbba.jpg
#                     malayan_civet_103_JPG.rf.bdb85ccf22cf2b12bb14eb83b31f683e.jpg
#                     malayan_civet_104_JPG.rf.43efccc55be3275e1ca30452c98e04f3.jpg
#                     malayan_civet_105_JPG.rf.a35ff27146e5303f7b113ddc24abc0a9.jpg
#                     ... and 215 more files
#                 labels/
#                     malayan_civet_100_JPG.rf.461cc946f446e54ac0a9da6f457d1a1c.txt
#                     malayan_civet_102_JPG.rf.79b6d3660ac8f8df7a59ea26d29dbbba.txt
#                     malayan_civet_103_JPG.rf.bdb85ccf22cf2b12bb14eb83b31f683e.txt
#                     malayan_civet_104_JPG.rf.43efccc55be3275e1ca30452c98e04f3.txt
#                     malayan_civet_105_JPG.rf.a35ff27146e5303f7b113ddc24abc0a9.txt
#                     ... and 215 more files
#             malayan porcupine/
#                 images/
#                     malayan_porcupine_100_JPG.rf.9bb261cf3b8b7988114c9d485dad5f03.jpg
#                     malayan_porcupine_102_JPG.rf.a196ee5e48fc7b98bb9574cf3eccdf98.jpg
#                     malayan_porcupine_103_JPG.rf.7c6ff22cce01bca769dd7e1777eb9f9a.jpg
#                     malayan_porcupine_104_JPG.rf.dee97d575568aa346b6f619ea8173c06.jpg
#                     malayan_porcupine_105_JPG.rf.7204c086fbf762de0a9277e3fc9d2d84.jpg
#                     ... and 254 more files
#                 labels/
#                     malayan_porcupine_100_JPG.rf.9bb261cf3b8b7988114c9d485dad5f03.txt
#                     malayan_porcupine_102_JPG.rf.a196ee5e48fc7b98bb9574cf3eccdf98.txt
#                     malayan_porcupine_103_JPG.rf.7c6ff22cce01bca769dd7e1777eb9f9a.txt
#                     malayan_porcupine_104_JPG.rf.dee97d575568aa346b6f619ea8173c06.txt
#                     malayan_porcupine_105_JPG.rf.7204c086fbf762de0a9277e3fc9d2d84.txt
#                     ... and 254 more files
#             marbled cat/
#                 images/
#                     marbled_cat_1_JPG.rf.42a48a90492ebebb77e989c2a2d34877.jpg
#                     marbled_cat_2_JPG.rf.6e18ef8aa87e2bdfaf91ef91e9685b63.jpg
#                     marbled_cat_3_JPG.rf.5f1fc1e7d5af34587c6af74dfe4bd998.jpg
#                     marbled_cat_4_JPG.rf.7eb35aa2d834edbb53c14e263a51dcf0.jpg
#                     marbled_cat_5_JPG.rf.74bd662adf9cd293a787bc27550f4ae9.jpg
#                 labels/
#                     marbled_cat_1_JPG.rf.42a48a90492ebebb77e989c2a2d34877.txt
#                     marbled_cat_2_JPG.rf.6e18ef8aa87e2bdfaf91ef91e9685b63.txt
#                     marbled_cat_3_JPG.rf.5f1fc1e7d5af34587c6af74dfe4bd998.txt
#                     marbled_cat_4_JPG.rf.7eb35aa2d834edbb53c14e263a51dcf0.txt
#                     marbled_cat_5_JPG.rf.74bd662adf9cd293a787bc27550f4ae9.txt
#             masked palm civet/
#                 images/
#                     masked_palm_civet_1_JPG.rf.3a1297bb46c83d6c01a7b634a71f5a76.jpg
#                     masked_palm_civet_2_JPG.rf.ed1b7ea117359ddf8017b93900b1c215.jpg
#                     masked_palm_civet_3_JPG.rf.43661faaddc361ccbef44eb89a844585.jpg
#                     masked_palm_civet_4_JPG.rf.aea1abc6642735938e7d4b76685cf519.jpg
#                     masked_palm_civet_5_JPG.rf.1af1466390847f0789b3c04d01ba7c8d.jpg
#                 labels/
#                     masked_palm_civet_1_JPG.rf.3a1297bb46c83d6c01a7b634a71f5a76.txt
#                     masked_palm_civet_2_JPG.rf.ed1b7ea117359ddf8017b93900b1c215.txt
#                     masked_palm_civet_3_JPG.rf.43661faaddc361ccbef44eb89a844585.txt
#                     masked_palm_civet_4_JPG.rf.aea1abc6642735938e7d4b76685cf519.txt
#                     masked_palm_civet_5_JPG.rf.1af1466390847f0789b3c04d01ba7c8d.txt
#             mongoose sp/
#                 images/
#                     mongoose_sp_100_JPG.rf.233d4bfea006e53a2f8ca7554c72ff31.jpg
#                     mongoose_sp_101_JPG.rf.fb3e9257a2e77927c494971b8ef1c74e.jpg
#                     mongoose_sp_102_JPG.rf.286a7c1b8d4cce4edfb0b64927d038bb.jpg
#                     mongoose_sp_103_JPG.rf.5139b5b42f61facd04950a378b87bf20.jpg
#                     mongoose_sp_107_JPG.rf.74014b3a277a381ea2069385bc8e875c.jpg
#                     ... and 121 more files
#                 labels/
#                     mongoose_sp_100_JPG.rf.233d4bfea006e53a2f8ca7554c72ff31.txt
#                     mongoose_sp_101_JPG.rf.fb3e9257a2e77927c494971b8ef1c74e.txt
#                     mongoose_sp_102_JPG.rf.286a7c1b8d4cce4edfb0b64927d038bb.txt
#                     mongoose_sp_103_JPG.rf.5139b5b42f61facd04950a378b87bf20.txt
#                     mongoose_sp_107_JPG.rf.74014b3a277a381ea2069385bc8e875c.txt
#                     ... and 121 more files
#             monitor lizard/
#                 images/
#                     monitor_lizard_10_JPG.rf.af83d00958a32683649e6740794a1533.jpg
#                     monitor_lizard_11_JPG.rf.096a72f2ae94c91b16798a4c7549727d.jpg
#                     monitor_lizard_13_JPG.rf.96280d1f393208a753713dc9bf2f4c17.jpg
#                     monitor_lizard_14_JPG.rf.c07b202c7313d64eeb445399d3a44954.jpg
#                     monitor_lizard_15_JPG.rf.d97c07ffbab77f97799ec68d6a4f7dde.jpg
#                     ... and 9 more files
#                 labels/
#                     monitor_lizard_10_JPG.rf.af83d00958a32683649e6740794a1533.txt
#                     monitor_lizard_11_JPG.rf.096a72f2ae94c91b16798a4c7549727d.txt
#                     monitor_lizard_13_JPG.rf.96280d1f393208a753713dc9bf2f4c17.txt
#                     monitor_lizard_14_JPG.rf.c07b202c7313d64eeb445399d3a44954.txt
#                     monitor_lizard_15_JPG.rf.d97c07ffbab77f97799ec68d6a4f7dde.txt
#                     ... and 9 more files
#             mouse sp/
#                 images/
#                     mouse_sp_11_JPG.rf.be74902acedb4e38223c14caf2e5b849.jpg
#                     mouse_sp_13_JPG.rf.3d610b43ba8f3ed48e272b9baf029ee7.jpg
#                     mouse_sp_14_JPG.rf.c57f5aa4e6f0e00104754225b74335cb.jpg
#                     mouse_sp_15_JPG.rf.32958d5f9b6e5278717f182139d3f9df.jpg
#                     mouse_sp_16_JPG.rf.23448b767be408b31e8d38b3b5b4b0de.jpg
#                     ... and 44 more files
#                 labels/
#                     mouse_sp_11_JPG.rf.be74902acedb4e38223c14caf2e5b849.txt
#                     mouse_sp_13_JPG.rf.3d610b43ba8f3ed48e272b9baf029ee7.txt
#                     mouse_sp_14_JPG.rf.c57f5aa4e6f0e00104754225b74335cb.txt
#                     mouse_sp_15_JPG.rf.32958d5f9b6e5278717f182139d3f9df.txt
#                     mouse_sp_16_JPG.rf.23448b767be408b31e8d38b3b5b4b0de.txt
#                     ... and 44 more files
#             mousedeer sp/
#                 images/
#                     mousedeer_sp_100_JPG.rf.95f677e2970151fd51457d6811d9a2e1.jpg
#                     mousedeer_sp_102_JPG.rf.cfa73dda85148b52731a6256466b313c.jpg
#                     mousedeer_sp_103_JPG.rf.070845459b86f9027b144244e5c31563.jpg
#                     mousedeer_sp_104_JPG.rf.3aef710c55d7ec101be5f72e6778c7a9.jpg
#                     mousedeer_sp_105_JPG.rf.65097709a688d2a0cd7a50b4ed93b1ca.jpg
#                     ... and 199 more files
#                 labels/
#                     mousedeer_sp_100_JPG.rf.95f677e2970151fd51457d6811d9a2e1.txt
#                     mousedeer_sp_102_JPG.rf.cfa73dda85148b52731a6256466b313c.txt
#                     mousedeer_sp_103_JPG.rf.070845459b86f9027b144244e5c31563.txt
#                     mousedeer_sp_104_JPG.rf.3aef710c55d7ec101be5f72e6778c7a9.txt
#                     mousedeer_sp_105_JPG.rf.65097709a688d2a0cd7a50b4ed93b1ca.txt
#                     ... and 199 more files
#             muntjac sp/
#                 images/
#                     munjact_sp_653_JPG.rf.609e6c7be15edf16501d24b204d9634a.jpg
#                     munjact_sp_654_JPG.rf.1e6ae9458e2e1a94d8cae34f9baec168.jpg
#                     munjact_sp_655_JPG.rf.188fbd30484c460c98f4737b276c4d60.jpg
#                     muntjac_sp_100_JPG.rf.770936a0dd408c75fd86a5fde2c08035.jpg
#                     muntjac_sp_102_JPG.rf.a4307f8af2fa488ec492884a7c0590ba.jpg
#                     ... and 229 more files
#                 labels/
#                     munjact_sp_653_JPG.rf.609e6c7be15edf16501d24b204d9634a.txt
#                     munjact_sp_654_JPG.rf.1e6ae9458e2e1a94d8cae34f9baec168.txt
#                     munjact_sp_655_JPG.rf.188fbd30484c460c98f4737b276c4d60.txt
#                     muntjac_sp_100_JPG.rf.770936a0dd408c75fd86a5fde2c08035.txt
#                     muntjac_sp_102_JPG.rf.a4307f8af2fa488ec492884a7c0590ba.txt
#                     ... and 229 more files
#             otter civet/
#                 images/
#                     otter_civet_1_JPG.rf.b19c8d93052b72f66d3431e3df12ba1f.jpg
#                 labels/
#                     otter_civet_1_JPG.rf.b19c8d93052b72f66d3431e3df12ba1f.txt
#             pangolin/
#                 images/
#                     pangolin_11_JPG.rf.0c339548b096b060f554fda9ca32389e.jpg
#                     pangolin_12_JPG.rf.c5ee6320d3e9749fe7ec9c35e30479ab.jpg
#                     pangolin_13_JPG.rf.1a86d20ec14e71682b541a4e29aa5254.jpg
#                     pangolin_14_JPG.rf.aad19197932610b25e8ec4e2caf11153.jpg
#                     pangolin_1_JPG.rf.8e7f370f2f6ee4b08a712c075559dce0.jpg
#                     ... and 5 more files
#                 labels/
#                     pangolin_11_JPG.rf.0c339548b096b060f554fda9ca32389e.txt
#                     pangolin_12_JPG.rf.c5ee6320d3e9749fe7ec9c35e30479ab.txt
#                     pangolin_13_JPG.rf.1a86d20ec14e71682b541a4e29aa5254.txt
#                     pangolin_14_JPG.rf.aad19197932610b25e8ec4e2caf11153.txt
#                     pangolin_1_JPG.rf.8e7f370f2f6ee4b08a712c075559dce0.txt
#                     ... and 5 more files
#             pig-tailed macaque/
#                 images/
#                     pig-tailed_macaque_102_JPG.rf.2ac7f0fef7f203dac969c7f8f204deed.jpg
#                     pig-tailed_macaque_103_JPG.rf.d2675f18bf051d1602134e2e6e6df7ab.jpg
#                     pig-tailed_macaque_104_JPG.rf.f177682f40f35fea6995e8ffbc7b8f08.jpg
#                     pig-tailed_macaque_105_JPG.rf.ca73036bc176c670e496f820ebb8531a.jpg
#                     pig-tailed_macaque_106_JPG.rf.7abc96c861925aa3ebc2198549e59458.jpg
#                     ... and 453 more files
#                 labels/
#                     pig-tailed_macaque_102_JPG.rf.2ac7f0fef7f203dac969c7f8f204deed.txt
#                     pig-tailed_macaque_103_JPG.rf.d2675f18bf051d1602134e2e6e6df7ab.txt
#                     pig-tailed_macaque_104_JPG.rf.f177682f40f35fea6995e8ffbc7b8f08.txt
#                     pig-tailed_macaque_105_JPG.rf.ca73036bc176c670e496f820ebb8531a.txt
#                     pig-tailed_macaque_106_JPG.rf.7abc96c861925aa3ebc2198549e59458.txt
#                     ... and 453 more files
#             pigeon sp/
#                 images/
#                     pigeon_sp_1_JPG.rf.db5ec5e729db5b06401e4411391bc577.jpg
#                     pigeon_sp_2_JPG.rf.c67ae4dfe5526429b45bf08bf9e12d30.jpg
#                 labels/
#                     pigeon_sp_1_JPG.rf.db5ec5e729db5b06401e4411391bc577.txt
#                     pigeon_sp_2_JPG.rf.c67ae4dfe5526429b45bf08bf9e12d30.txt
#             rat sp/
#                 images/
#                     rat_sp_100_JPG.rf.8872e1e6c389b88db6800caba028aa29.jpg
#                     rat_sp_103_JPG.rf.e9dfc5e3317f3aa300a8b4c09313ddde.jpg
#                     rat_sp_104_JPG.rf.b0e8350dfb62e4f7bc492e8d598be5e6.jpg
#                     rat_sp_105_JPG.rf.425188622a94988065a8d8736aae012e.jpg
#                     rat_sp_106_JPG.rf.87239b5b051bc77f9fbc28d753fa5909.jpg
#                     ... and 71 more files
#                 labels/
#                     rat_sp_100_JPG.rf.8872e1e6c389b88db6800caba028aa29.txt
#                     rat_sp_103_JPG.rf.e9dfc5e3317f3aa300a8b4c09313ddde.txt
#                     rat_sp_104_JPG.rf.b0e8350dfb62e4f7bc492e8d598be5e6.txt
#                     rat_sp_105_JPG.rf.425188622a94988065a8d8736aae012e.txt
#                     rat_sp_106_JPG.rf.87239b5b051bc77f9fbc28d753fa5909.txt
#                     ... and 71 more files
#             roughneck monitor lizard/
#                 images/
#                     roughneck_monitor_lizard_1_JPG.rf.27f2a87acb204fad32b777efaa44170e.jpg
#                     roughneck_monitor_lizard_2_JPG.rf.3ca36785b1769c2fd29ae257a19ca3c8.jpg
#                 labels/
#                     roughneck_monitor_lizard_1_JPG.rf.27f2a87acb204fad32b777efaa44170e.txt
#                     roughneck_monitor_lizard_2_JPG.rf.3ca36785b1769c2fd29ae257a19ca3c8.txt
#             roulroul/
#                 images/
#                     roulroul_13_JPG.rf.5b2243e359b08d822275b4eb5d5abffa.jpg
#                     roulroul_14_JPG.rf.a57d4fabbe8d30d27429a2b986954789.jpg
#                     roulroul_15_JPG.rf.7e91d6eda1f201ab32e905aa90e38528.jpg
#                     roulroul_16_JPG.rf.d54aee1058a5a67112331f2dba04bb49.jpg
#                     roulroul_17_JPG.rf.87f5d480421b1df929a49e31df45a51d.jpg
#                     ... and 54 more files
#                 labels/
#                     roulroul_13_JPG.rf.5b2243e359b08d822275b4eb5d5abffa.txt
#                     roulroul_14_JPG.rf.a57d4fabbe8d30d27429a2b986954789.txt
#                     roulroul_15_JPG.rf.7e91d6eda1f201ab32e905aa90e38528.txt
#                     roulroul_16_JPG.rf.d54aee1058a5a67112331f2dba04bb49.txt
#                     roulroul_17_JPG.rf.87f5d480421b1df929a49e31df45a51d.txt
#                     ... and 54 more files
#             sambar deer/
#                 images/
#                     sambar_deer_102_JPG.rf.bee61d301d012e7a777f6cbb4bf5c417.jpg
#                     sambar_deer_105_JPG.rf.3243aa92384cbda77548238a258fbce6.jpg
#                     sambar_deer_106_JPG.rf.45e098443166b36087f521692013a4b6.jpg
#                     sambar_deer_107_JPG.rf.bfe2dcdab3d2574d37ed40db55b74c6b.jpg
#                     sambar_deer_108_JPG.rf.d60552897a36844c8c5a66406ac8d50d.jpg
#                     ... and 399 more files
#                 labels/
#                     sambar_deer_102_JPG.rf.bee61d301d012e7a777f6cbb4bf5c417.txt
#                     sambar_deer_105_JPG.rf.3243aa92384cbda77548238a258fbce6.txt
#                     sambar_deer_106_JPG.rf.45e098443166b36087f521692013a4b6.txt
#                     sambar_deer_107_JPG.rf.bfe2dcdab3d2574d37ed40db55b74c6b.txt
#                     sambar_deer_108_JPG.rf.d60552897a36844c8c5a66406ac8d50d.txt
#                     ... and 399 more files
#             small-toothed palm civet/
#                 images/
#                     small-toothed_palm_civet_11_JPG.rf.53a98700333ba6505fe85e8bd47c54f4.jpg
#                     small-toothed_palm_civet_12_JPG.rf.61144954f5b32dfc1762afe0781091d1.jpg
#                     small-toothed_palm_civet_1_JPG.rf.72c6bea3446ca8c68de89b25c06c7eb1.jpg
#                     small-toothed_palm_civet_2_JPG.rf.5a7d5730eb3cee7a073f02ff111a2e4f.jpg
#                     small-toothed_palm_civet_3_JPG.rf.36c9f70dce5e043a383dd566fbddb918.jpg
#                     ... and 5 more files
#                 labels/
#                     small-toothed_palm_civet_11_JPG.rf.53a98700333ba6505fe85e8bd47c54f4.txt
#                     small-toothed_palm_civet_12_JPG.rf.61144954f5b32dfc1762afe0781091d1.txt
#                     small-toothed_palm_civet_1_JPG.rf.72c6bea3446ca8c68de89b25c06c7eb1.txt
#                     small-toothed_palm_civet_2_JPG.rf.5a7d5730eb3cee7a073f02ff111a2e4f.txt
#                     small-toothed_palm_civet_3_JPG.rf.36c9f70dce5e043a383dd566fbddb918.txt
#                     ... and 5 more files
#             squirrel sp/
#                 images/
#                     squirrel_sp_10_JPG.rf.678cf452489262281ce19b66d178e781.jpg
#                     squirrel_sp_12_JPG.rf.697dc440cdebc7a37cd1912f9ec00b5f.jpg
#                     squirrel_sp_13_JPG.rf.ae40a642914db40dab5498aeacbc9094.jpg
#                     squirrel_sp_14_JPG.rf.bbcaf04c49e8bd658cd309a63363f52d.jpg
#                     squirrel_sp_15_JPG.rf.b68eccb883e2267c48d3704d65bd9b25.jpg
#                     ... and 12 more files
#                 labels/
#                     squirrel_sp_10_JPG.rf.678cf452489262281ce19b66d178e781.txt
#                     squirrel_sp_12_JPG.rf.697dc440cdebc7a37cd1912f9ec00b5f.txt
#                     squirrel_sp_13_JPG.rf.ae40a642914db40dab5498aeacbc9094.txt
#                     squirrel_sp_14_JPG.rf.bbcaf04c49e8bd658cd309a63363f52d.txt
#                     squirrel_sp_15_JPG.rf.b68eccb883e2267c48d3704d65bd9b25.txt
#                     ... and 12 more files
#             sun bear/
#                 images/
#                     sun_bear_100_JPG.rf.923efb04cad23fd5a41ca7005e2db4aa.jpg
#                     sun_bear_101_JPG.rf.b6780e2f1a6556c74be7ad847a9eeb2b.jpg
#                     sun_bear_102_JPG.rf.454f1e8951d35368304d80cc54fd76ad.jpg
#                     sun_bear_103_JPG.rf.61f02b635a79e99f0db0b8d970eb826d.jpg
#                     sun_bear_104_JPG.rf.37669ad218aba1feb009f614ab75281b.jpg
#                     ... and 307 more files
#                 labels/
#                     sun_bear_100_JPG.rf.923efb04cad23fd5a41ca7005e2db4aa.txt
#                     sun_bear_101_JPG.rf.b6780e2f1a6556c74be7ad847a9eeb2b.txt
#                     sun_bear_102_JPG.rf.454f1e8951d35368304d80cc54fd76ad.txt
#                     sun_bear_103_JPG.rf.61f02b635a79e99f0db0b8d970eb826d.txt
#                     sun_bear_104_JPG.rf.37669ad218aba1feb009f614ab75281b.txt
#                     ... and 307 more files
#             thick-spined porcupine/
#                 images/
#                     thick-spined_porcupine_100_JPG.rf.effce3bf79661befbd201d0b48df1d4a.jpg
#                     thick-spined_porcupine_102_JPG.rf.f3caf6d88d73bfa6d2a9c1452b5c1412.jpg
#                     thick-spined_porcupine_103_JPG.rf.4355134ab238720a6aa264449e4a0723.jpg
#                     thick-spined_porcupine_104_JPG.rf.969d89bec122a37c4c702130f8f400ef.jpg
#                     thick-spined_porcupine_105_JPG.rf.7a4d20715ac24e8ccf739f88e568c2f3.jpg
#                     ... and 232 more files
#                 labels/
#                     thick-spined_porcupine_100_JPG.rf.effce3bf79661befbd201d0b48df1d4a.txt
#                     thick-spined_porcupine_102_JPG.rf.f3caf6d88d73bfa6d2a9c1452b5c1412.txt
#                     thick-spined_porcupine_103_JPG.rf.4355134ab238720a6aa264449e4a0723.txt
#                     thick-spined_porcupine_104_JPG.rf.969d89bec122a37c4c702130f8f400ef.txt
#                     thick-spined_porcupine_105_JPG.rf.7a4d20715ac24e8ccf739f88e568c2f3.txt
#                     ... and 232 more files
#             treeshrew sp/
#                 images/
#                     treeshrew_sp_100_JPG.rf.ff4ac07c197b2cd0ac141c7340210f33.jpg
#                     treeshrew_sp_101_JPG.rf.9ae4f7244f5b372354b00e8d71f1aff3.jpg
#                     treeshrew_sp_102_JPG.rf.5ffc104a6b9e4efb7512f2b3d6e4a2ac.jpg
#                     treeshrew_sp_103_JPG.rf.7c9c4ee54d5b70f520fd0416041b1b64.jpg
#                     treeshrew_sp_107_JPG.rf.d738441232992214e33ab73885cb409f.jpg
#                     ... and 120 more files
#                 labels/
#                     treeshrew_sp_100_JPG.rf.ff4ac07c197b2cd0ac141c7340210f33.txt
#                     treeshrew_sp_101_JPG.rf.9ae4f7244f5b372354b00e8d71f1aff3.txt
#                     treeshrew_sp_102_JPG.rf.5ffc104a6b9e4efb7512f2b3d6e4a2ac.txt
#                     treeshrew_sp_103_JPG.rf.7c9c4ee54d5b70f520fd0416041b1b64.txt
#                     treeshrew_sp_107_JPG.rf.d738441232992214e33ab73885cb409f.txt
#                     ... and 120 more files
#             tufted squirrel/
#                 images/
#                     tufted_squirrel_1_JPG.rf.4cc632a0260ebffe1b2bb1c221b32d34.jpg
#                 labels/
#                     tufted_squirrel_1_JPG.rf.4cc632a0260ebffe1b2bb1c221b32d34.txt
#             white fronted langur/
#                 images/
#                     white_fronted_langur_10_JPG.rf.81c181558a0a5451b709bd69fdc2eb9a.jpg
#                     white_fronted_langur_11_JPG.rf.7df9dc8e349a8655ddebffc82cf7f411.jpg
#                     white_fronted_langur_15_JPG.rf.4bd5c65e9d6b773338e8acf13c25ea3f.jpg
#                     white_fronted_langur_16_JPG.rf.8bdb8b68d1dd2d7eede734ce2366fc2f.jpg
#                     white_fronted_langur_17_JPG.rf.311174c01cf7d826a76ed2abde214b73.jpg
#                     ... and 7 more files
#                 labels/
#                     white_fronted_langur_10_JPG.rf.81c181558a0a5451b709bd69fdc2eb9a.txt
#                     white_fronted_langur_11_JPG.rf.7df9dc8e349a8655ddebffc82cf7f411.txt
#                     white_fronted_langur_15_JPG.rf.4bd5c65e9d6b773338e8acf13c25ea3f.txt
#                     white_fronted_langur_16_JPG.rf.8bdb8b68d1dd2d7eede734ce2366fc2f.txt
#                     white_fronted_langur_17_JPG.rf.311174c01cf7d826a76ed2abde214b73.txt
#                     ... and 7 more files
#             yellow-throated marten/
#                 images/
#                     yellow-throated_marten_10_JPG.rf.61823dc9c9a84e497984de6f704330e7.jpg
#                     yellow-throated_marten_13_JPG.rf.37f6510f889dd35afa100908aa4ac9d9.jpg
#                     yellow-throated_marten_14_JPG.rf.54d4ba2fdb3a07d1cfc345887e76cee8.jpg
#                     yellow-throated_marten_15_JPG.rf.b9509f7113d527939e06370208b0c18d.jpg
#                     yellow-throated_marten_16_JPG.rf.0d82dcb9b2c9e55f661e40dabc6cd710.jpg
#                     ... and 7 more files
#                 labels/
#                     yellow-throated_marten_10_JPG.rf.61823dc9c9a84e497984de6f704330e7.txt
#                     yellow-throated_marten_13_JPG.rf.37f6510f889dd35afa100908aa4ac9d9.txt
#                     yellow-throated_marten_14_JPG.rf.54d4ba2fdb3a07d1cfc345887e76cee8.txt
#                     yellow-throated_marten_15_JPG.rf.b9509f7113d527939e06370208b0c18d.txt
#                     yellow-throated_marten_16_JPG.rf.0d82dcb9b2c9e55f661e40dabc6cd710.txt
#                     ... and 7 more files
#         val/
#             banded civet/
#                 labels.cache
#                 images/
#                     banded_civet_101_JPG.rf.bd59def1a0a803cb24f10e50352297c2.jpg
#                     banded_civet_109_JPG.rf.fae845f3dcde3a37fd378021fff6e05f.jpg
#                     banded_civet_110_JPG.rf.400178aa06dd23714cbc1020857aca4f.jpg
#                     banded_civet_111_JPG.rf.6ed58c49dab3258fd4766b92e6d26cd6.jpg
#                     banded_civet_133_JPG.rf.9ce6295cc5898d0f812cb791a1a7b2b9.jpg
#                     ... and 32 more files
#                 labels/
#                     banded_civet_101_JPG.rf.bd59def1a0a803cb24f10e50352297c2.txt
#                     banded_civet_109_JPG.rf.fae845f3dcde3a37fd378021fff6e05f.txt
#                     banded_civet_110_JPG.rf.400178aa06dd23714cbc1020857aca4f.txt
#                     banded_civet_111_JPG.rf.6ed58c49dab3258fd4766b92e6d26cd6.txt
#                     banded_civet_133_JPG.rf.9ce6295cc5898d0f812cb791a1a7b2b9.txt
#                     ... and 32 more files
#             banded linsang/
#                 images/
#                     banded_linsang_1_JPG.rf.68761114b309fb82e7c64bc4ec48ea81.jpg
#                 labels/
#                     banded_linsang_1_JPG.rf.68761114b309fb82e7c64bc4ec48ea81.txt
#             bay cat/
#                 images/
#                     bay_cat_1_JPG.rf.e2eed92a76dfb88b628e1d880381faf0.jpg
#                 labels/
#                     bay_cat_1_JPG.rf.e2eed92a76dfb88b628e1d880381faf0.txt
#             bearded pig/
#                 images/
#                     bearded_pig_105_JPG.rf.c9ef9f92fb21c2b9e2cd419b2ff2f26a.jpg
#                     bearded_pig_117_JPG.rf.d14803cc932733b351cfe520b5257a9f.jpg
#                     bearded_pig_118_JPG.rf.46be161264b86107701835b3bb276b3e.jpg
#                     bearded_pig_128_JPG.rf.61c511892fccf1b2fdfe222c67eb0565.jpg
#                     bearded_pig_129_JPG.rf.8a020626b4291ab129c33d780a799420.jpg
#                     ... and 58 more files
#                 labels/
#                     bearded_pig_105_JPG.rf.c9ef9f92fb21c2b9e2cd419b2ff2f26a.txt
#                     bearded_pig_117_JPG.rf.d14803cc932733b351cfe520b5257a9f.txt
#                     bearded_pig_118_JPG.rf.46be161264b86107701835b3bb276b3e.txt
#                     bearded_pig_128_JPG.rf.61c511892fccf1b2fdfe222c67eb0565.txt
#                     bearded_pig_129_JPG.rf.8a020626b4291ab129c33d780a799420.txt
#                     ... and 58 more files
#             binturong/
#                 images/
#                     binturong_1_JPG.rf.50e29e9b17f31fefabbcbfd36ffe7e0b.jpg
#                 labels/
#                     binturong_1_JPG.rf.50e29e9b17f31fefabbcbfd36ffe7e0b.txt
#             bird sp/
#                 images/
#                     bird_sp_1_JPG.rf.d36c890225abc337183037ef2608307d.jpg
#                 labels/
#                     bird_sp_1_JPG.rf.d36c890225abc337183037ef2608307d.txt
#             bulwer's pheasant/
#                 images/
#                     bulwer-s_pheasant_103_JPG.rf.dfbfb2561f85d3f6cdf9e5ea59dac557.jpg
#                     bulwer-s_pheasant_107_JPG.rf.4b66e0d879a10419f7f96194957160ef.jpg
#                     bulwer-s_pheasant_114_JPG.rf.e6a189c2fdf337dc08c5ff73001fe4f0.jpg
#                     bulwer-s_pheasant_116_JPG.rf.f67456003092f57efda450b7d426e18e.jpg
#                     bulwer-s_pheasant_117_JPG.rf.f35cc1cf7acc28b535f1b3f4654bfa4f.jpg
#                     ... and 15 more files
#                 labels/
#                     bulwer-s_pheasant_103_JPG.rf.dfbfb2561f85d3f6cdf9e5ea59dac557.txt
#                     bulwer-s_pheasant_107_JPG.rf.4b66e0d879a10419f7f96194957160ef.txt
#                     bulwer-s_pheasant_114_JPG.rf.e6a189c2fdf337dc08c5ff73001fe4f0.txt
#                     bulwer-s_pheasant_116_JPG.rf.f67456003092f57efda450b7d426e18e.txt
#                     bulwer-s_pheasant_117_JPG.rf.f35cc1cf7acc28b535f1b3f4654bfa4f.txt
#                     ... and 15 more files
#             great argus pheasant/
#                 images/
#                     great_argus_pheasant_12023_JPG.rf.df0635c9304683632f97a18354c4877a.jpg
#                     great_argus_pheasant_12039_JPG.rf.f6eeff3722bd78e2bda0e2ce3e63c28e.jpg
#                     great_argus_pheasant_12040_JPG.rf.607870735c3c7b108c91446b427be26c.jpg
#                     great_argus_pheasant_12042_JPG.rf.bb39974b013e53a34cd7a431cb7b4a34.jpg
#                     great_argus_pheasant_12044_JPG.rf.fc4234c72c2ac62fe076976176499783.jpg
#                     ... and 63 more files
#                 labels/
#                     great_argus_pheasant_12023_JPG.rf.df0635c9304683632f97a18354c4877a.txt
#                     great_argus_pheasant_12039_JPG.rf.f6eeff3722bd78e2bda0e2ce3e63c28e.txt
#                     great_argus_pheasant_12040_JPG.rf.607870735c3c7b108c91446b427be26c.txt
#                     great_argus_pheasant_12042_JPG.rf.bb39974b013e53a34cd7a431cb7b4a34.txt
#                     great_argus_pheasant_12044_JPG.rf.fc4234c72c2ac62fe076976176499783.txt
#                     ... and 63 more files
#             ground tufted squirrel/
#                 images/
#                     ground_tufted_squirrel_4_JPG.rf.27ceccfa1be806f6780906ae48b40446.jpg
#                 labels/
#                     ground_tufted_squirrel_4_JPG.rf.27ceccfa1be806f6780906ae48b40446.txt
#             human/
#                 images/
#                     human_102_JPG.rf.21b650a7740fc49361cce592c35e4590.jpg
#                     human_107_JPG.rf.a67a2cb71901cf2bfa3ca4082196c845.jpg
#                     human_108_JPG.rf.0e6bc3ec08db3c96a509f722811a0735.jpg
#                     human_111_JPG.rf.2e6423fa4864b5acacbc4818fd8d2f66.jpg
#                     human_12_JPG.rf.74c1e66a5a2b72b39c687e5822ee47d7.jpg
#                     ... and 35 more files
#                 labels/
#                     human_102_JPG.rf.21b650a7740fc49361cce592c35e4590.txt
#                     human_107_JPG.rf.a67a2cb71901cf2bfa3ca4082196c845.txt
#                     human_108_JPG.rf.0e6bc3ec08db3c96a509f722811a0735.txt
#                     human_111_JPG.rf.2e6423fa4864b5acacbc4818fd8d2f66.txt
#                     human_12_JPG.rf.74c1e66a5a2b72b39c687e5822ee47d7.txt
#                     ... and 35 more files
#             leopard cat/
#                 images/
#                     leopard_cat_103_JPG.rf.2df5fcf547a90baa07caa9841c4b2793.jpg
#                     leopard_cat_107_JPG.rf.e787e1725399dbe112c14adf06ba19b3.jpg
#                     leopard_cat_114_JPG.rf.715ef44a8aab5f69f1c363cfeef7d960.jpg
#                     leopard_cat_116_JPG.rf.7f419d0dc7d4ac41110b8aaed61e355d.jpg
#                     leopard_cat_118_JPG.rf.7b3bc5b529e92fbd49c4f2fdba538ad4.jpg
#                     ... and 16 more files
#                 labels/
#                     leopard_cat_103_JPG.rf.2df5fcf547a90baa07caa9841c4b2793.txt
#                     leopard_cat_107_JPG.rf.e787e1725399dbe112c14adf06ba19b3.txt
#                     leopard_cat_114_JPG.rf.715ef44a8aab5f69f1c363cfeef7d960.txt
#                     leopard_cat_116_JPG.rf.7f419d0dc7d4ac41110b8aaed61e355d.txt
#                     leopard_cat_118_JPG.rf.7b3bc5b529e92fbd49c4f2fdba538ad4.txt
#                     ... and 16 more files
#             long-tailed macaque/
#                 images/
#                     long-tailed_macaque_104_JPG.rf.5636cbf354769079a08572c111915f5e.jpg
# ...
#                 labels/
#                     squirrel_sp_10_JPG.rf.678cf452489262281ce19b66d178e781.txt
#                     squirrel_sp_14_JPG.rf.bbcaf04c49e8bd658cd309a63363f52d.txt
#                     squirrel_sp_27_JPG.rf.c85288e4a7d3507e78f993cdcc087f0e.txt
#             sun bear/
#                 images/
#                     sun_bear_103_JPG.rf.61f02b635a79e99f0db0b8d970eb826d.jpg
#                     sun_bear_118_JPG.rf.995ca6e5dd5f81736d29920681e364b5.jpg
#                     sun_bear_119_JPG.rf.c1ca895d0e5ebd73dc07741916f84624.jpg
#                     sun_bear_123_JPG.rf.baebb0d3249c4ec3d2136e51529e2d46.jpg
#                     sun_bear_178_JPG.rf.52243f5bcffef5dfc9fbf2f4f2d52c5e.jpg
#                     ... and 57 more files
#                 labels/
#                     sun_bear_103_JPG.rf.61f02b635a79e99f0db0b8d970eb826d.txt
#                     sun_bear_118_JPG.rf.995ca6e5dd5f81736d29920681e364b5.txt
#                     sun_bear_119_JPG.rf.c1ca895d0e5ebd73dc07741916f84624.txt
#                     sun_bear_123_JPG.rf.baebb0d3249c4ec3d2136e51529e2d46.txt
#                     sun_bear_178_JPG.rf.52243f5bcffef5dfc9fbf2f4f2d52c5e.txt
#                     ... and 57 more files
#             thick-spined porcupine/
#                 images/
#                     thick-spined_porcupine_102_JPG.rf.f3caf6d88d73bfa6d2a9c1452b5c1412.jpg
#                     thick-spined_porcupine_107_JPG.rf.39385b6c7f0f75d3fb5948eb12a0c71d.jpg
#                     thick-spined_porcupine_108_JPG.rf.92f5dde94a002f0a0fb0f6dd5fcb06c2.jpg
#                     thick-spined_porcupine_109_JPG.rf.5157e35f398d49ea6dcae4ce4a5c7b0b.jpg
#                     thick-spined_porcupine_126_JPG.rf.fd61c94183be78ed7a945d3949e290bb.jpg
#                     ... and 42 more files
#                 labels/
#                     thick-spined_porcupine_102_JPG.rf.f3caf6d88d73bfa6d2a9c1452b5c1412.txt
#                     thick-spined_porcupine_107_JPG.rf.39385b6c7f0f75d3fb5948eb12a0c71d.txt
#                     thick-spined_porcupine_108_JPG.rf.92f5dde94a002f0a0fb0f6dd5fcb06c2.txt
#                     thick-spined_porcupine_109_JPG.rf.5157e35f398d49ea6dcae4ce4a5c7b0b.txt
#                     thick-spined_porcupine_126_JPG.rf.fd61c94183be78ed7a945d3949e290bb.txt
#                     ... and 42 more files
#             treeshrew sp/
#                 images/
#                     treeshrew_sp_103_JPG.rf.7c9c4ee54d5b70f520fd0416041b1b64.jpg
#                     treeshrew_sp_107_JPG.rf.d738441232992214e33ab73885cb409f.jpg
#                     treeshrew_sp_115_JPG.rf.eace2782862b0d05496feec0a4093a58.jpg
#                     treeshrew_sp_118_JPG.rf.421ca9d66055051f142557c0e466a00a.jpg
#                     treeshrew_sp_11_JPG.rf.64fa5c8271883917a39d7d9a8ce077a3.jpg
#                     ... and 20 more files
#                 labels/
#                     treeshrew_sp_103_JPG.rf.7c9c4ee54d5b70f520fd0416041b1b64.txt
#                     treeshrew_sp_107_JPG.rf.d738441232992214e33ab73885cb409f.txt
#                     treeshrew_sp_115_JPG.rf.eace2782862b0d05496feec0a4093a58.txt
#                     treeshrew_sp_118_JPG.rf.421ca9d66055051f142557c0e466a00a.txt
#                     treeshrew_sp_11_JPG.rf.64fa5c8271883917a39d7d9a8ce077a3.txt
#                     ... and 20 more files
#             tufted squirrel/
#                 images/
#                     tufted_squirrel_1_JPG.rf.4cc632a0260ebffe1b2bb1c221b32d34.jpg
#                 labels/
#                     tufted_squirrel_1_JPG.rf.4cc632a0260ebffe1b2bb1c221b32d34.txt
#             white fronted langur/
#                 images/
#                     white_fronted_langur_11_JPG.rf.7df9dc8e349a8655ddebffc82cf7f411.jpg
#                     white_fronted_langur_7_JPG.rf.d507d01d4d42f30a61879d7b1806eae5.jpg
#                 labels/
#                     white_fronted_langur_11_JPG.rf.7df9dc8e349a8655ddebffc82cf7f411.txt
#                     white_fronted_langur_7_JPG.rf.d507d01d4d42f30a61879d7b1806eae5.txt
#             yellow-throated marten/
#                 images/
#                     yellow-throated_marten_13_JPG.rf.37f6510f889dd35afa100908aa4ac9d9.jpg
#                     yellow-throated_marten_7_JPG.rf.a57cdc11861202fd6e415e59b21ad67a.jpg
#                 labels/
#                     yellow-throated_marten_13_JPG.rf.37f6510f889dd35afa100908aa4ac9d9.txt
#                     yellow-throated_marten_7_JPG.rf.a57cdc11861202fd6e415e59b21ad67a.txt
#
# Attempting to load test dataset...
# Number of classes: 38
# Found potential split directory: /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test
# Using split directory: /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test
# Found directory for species banded civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/banded civet
# Found directory for species banded civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/banded civet/images
# Warning: No images found for species banded civet
# Found directory for species banded linsang at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/banded linsang
# Found directory for species banded linsang at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/banded linsang/images
# Warning: No images found for species banded linsang
# Found directory for species bay cat at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bay cat
# Found directory for species bay cat at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bay cat/images
# Warning: No images found for species bay cat
# Found directory for species bearded pig at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bearded pig
# Found directory for species bearded pig at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bearded pig/images
# Warning: No images found for species bearded pig
# Found directory for species binturong at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/binturong
# Found directory for species binturong at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/binturong/images
# Warning: No images found for species binturong
# Found directory for species bird sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bird sp
# Found directory for species bird sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bird sp/images
# Warning: No images found for species bird sp
# Found directory for species bulwer's pheasant at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bulwer's pheasant
# Found directory for species bulwer's pheasant at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/bulwer's pheasant/images
# Warning: No images found for species bulwer's pheasant
# Found directory for species great argus pheasant at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/great argus pheasant
# Found directory for species great argus pheasant at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/great argus pheasant/images
# Warning: No images found for species great argus pheasant
# Warning: No images found for species ground tufted squirrel
# Found directory for species human at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/human
# Found 5 images for species human
# Found directory for species leopard cat at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/leopard cat
# Found directory for species leopard cat at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/leopard cat/images
# Warning: No images found for species leopard cat
# Found directory for species long-tailed macaque at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/long-tailed macaque
# Found directory for species long-tailed macaque at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/long-tailed macaque/images
# Warning: No images found for species long-tailed macaque
# Found directory for species long-tailed porcupine at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/long-tailed porcupine
# Found directory for species long-tailed porcupine at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/long-tailed porcupine/images
# Warning: No images found for species long-tailed porcupine
# Found directory for species malayan civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/malayan civet
# Found directory for species malayan civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/malayan civet/images
# Warning: No images found for species malayan civet
# Found directory for species malayan porcupine at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/malayan porcupine
# Found directory for species malayan porcupine at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/malayan porcupine/images
# Warning: No images found for species malayan porcupine
# Found directory for species marbled cat at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/marbled cat
# Found directory for species marbled cat at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/marbled cat/images
# Warning: No images found for species marbled cat
# Found directory for species masked palm civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/masked palm civet
# Found directory for species masked palm civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/masked palm civet/images
# Warning: No images found for species masked palm civet
# Found directory for species mongoose sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/mongoose sp
# Found directory for species mongoose sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/mongoose sp/images
# Warning: No images found for species mongoose sp
# Found directory for species monitor lizard at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/monitor lizard
# Found directory for species monitor lizard at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/monitor lizard/images
# Warning: No images found for species monitor lizard
# Found directory for species mouse sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/mouse sp
# Found directory for species mouse sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/mouse sp/images
# Warning: No images found for species mouse sp
# Found directory for species mousedeer sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/mousedeer sp
# Found directory for species mousedeer sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/mousedeer sp/images
# Warning: No images found for species mousedeer sp
# Found directory for species muntjac sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/muntjac sp
# Found directory for species muntjac sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/muntjac sp/images
# Warning: No images found for species muntjac sp
# Found directory for species otter civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/otter civet
# Found directory for species otter civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/otter civet/images
# Warning: No images found for species otter civet
# Found directory for species pangolin at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/pangolin
# Found directory for species pangolin at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/pangolin/images
# Warning: No images found for species pangolin
# Found directory for species pig-tailed macaque at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/pig-tailed macaque
# Found directory for species pig-tailed macaque at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/pig-tailed macaque/images
# Warning: No images found for species pig-tailed macaque
# Found directory for species pigeon sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/pigeon sp
# Found directory for species pigeon sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/pigeon sp/images
# Warning: No images found for species pigeon sp
# Found directory for species rat sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/rat sp
# Found directory for species rat sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/rat sp/images
# Warning: No images found for species rat sp
# Found directory for species roughneck monitor lizard at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/roughneck monitor lizard
# Found directory for species roughneck monitor lizard at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/roughneck monitor lizard/images
# Warning: No images found for species roughneck monitor lizard
# Found directory for species roulroul at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/roulroul
# Found directory for species roulroul at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/roulroul/images
# Warning: No images found for species roulroul
# Found directory for species sambar deer at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/sambar deer
# Found directory for species sambar deer at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/sambar deer/images
# Warning: No images found for species sambar deer
# Found directory for species small-toothed palm civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/small-toothed palm civet
# Found directory for species small-toothed palm civet at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/small-toothed palm civet/images
# Warning: No images found for species small-toothed palm civet
# Found directory for species squirrel sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/squirrel sp
# Found directory for species squirrel sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/squirrel sp/images
# Warning: No images found for species squirrel sp
# Found directory for species sun bear at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/sun bear
# Found directory for species sun bear at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/sun bear/images
# Warning: No images found for species sun bear
# Found directory for species thick-spined porcupine at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/thick-spined porcupine
# Found directory for species thick-spined porcupine at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/thick-spined porcupine/images
# Warning: No images found for species thick-spined porcupine
# Found directory for species treeshrew sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/treeshrew sp
# Found directory for species treeshrew sp at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/treeshrew sp/images
# Warning: No images found for species treeshrew sp
# Warning: No images found for species tufted squirrel
# Found directory for species white fronted langur at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/white fronted langur
# Found directory for species white fronted langur at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/white fronted langur/images
# Warning: No images found for species white fronted langur
# Found directory for species yellow-throated marten at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/yellow-throated marten
# Found directory for species yellow-throated marten at /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/yellow-throated marten/images
# Warning: No images found for species yellow-throated marten
#
# Total images found for test split: 5
#
# Sample image paths:
# /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/human/images/human_199.jpeg
# /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/human/images/human_206.jpeg
# /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/human/images/human_211.jpeg
# /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/human/images/human_225.jpeg
# /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/test/human/images/human_227.jpeg
#
# Success! Found test dataset.
# Number of test images: 5

# %%
import torch
import timm
import json
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve, roc_curve, auc
from tqdm.notebook import tqdm

# Modify dataset class to load validation data
class WildlifeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = Path(root_dir)
        self.transform = transform
        self.images = []
        self.labels = []

        # Load class mappings
        with open(CONFIG_PATH, 'r') as f:
            self.class_info = json.load(f)

        self.num_classes = len(self.class_info['class_mapping'])
        print(f"Number of classes: {self.num_classes}")

        # Use validation split
        split_dir = self.root_dir / 'splits' / 'val'
        print(f"Using validation directory: {split_dir}")

        # Load images for each species
        for species_name, class_id in self.class_info['class_mapping'].items():
            species_dir = split_dir / species_name / 'images'
            if species_dir.exists():
                image_paths = list(species_dir.glob('*.jpg')) + list(species_dir.glob('*.jpeg'))
                if image_paths:
                    self.images.extend(image_paths)
                    self.labels.extend([class_id] * len(image_paths))
                    print(f"Found {len(image_paths)} images for species {species_name}")

        print(f"\nTotal images found: {len(self.images)}")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)

        return image, label

# Setup transforms
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load model
print("\nInitializing model...")
model = timm.create_model('tf_efficientnet_b2', pretrained=False, num_classes=38)
state_dict = torch.load(MODEL_PATH, map_location='cuda' if torch.cuda.is_available() else 'cpu')
state_dict = {k.replace('model.', ''): v for k, v in state_dict.items()}
model.load_state_dict(state_dict)
model.eval()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
print(f"Model loaded and moved to {device}")

# Load validation dataset
print("\nLoading validation dataset...")
val_dataset = WildlifeDataset(DATA_DIR, transform=val_transform)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)

# Collect predictions
print("\nRunning predictions...")
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in tqdm(val_loader, desc="Evaluating"):
        images = images.to(device)
        outputs = model(images)
        probabilities = torch.softmax(outputs, dim=1)
        _, predictions = torch.max(outputs, 1)

        all_probs.extend(probabilities.cpu().numpy())
        all_preds.extend(predictions.cpu().numpy())
        all_labels.extend(labels.numpy())

all_probs = np.array(all_probs)
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# Get class names
idx_to_class = {v: k for k, v in val_dataset.class_info['class_mapping'].items()}
class_names = [idx_to_class[i] for i in range(len(idx_to_class))]

print("\nGenerating visualizations...")

# Create analysis directory if it doesn't exist
ANALYSIS_DIR = PROJECT_DIR / 'outputs' / 'analysis'
ANALYSIS_DIR.mkdir(parents=True, exist_ok=True)

# 1. Confusion Matrix
plt.figure(figsize=(20, 20))
cm = confusion_matrix(all_labels, all_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=45)
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.close()

# 2. Per-class Accuracy
plt.figure(figsize=(20, 8))
class_accuracy = cm.diagonal() / cm.sum(axis=1)
plt.bar(class_names, class_accuracy)
plt.title('Per-class Accuracy')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Accuracy')
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'per_class_accuracy.png', dpi=300, bbox_inches='tight')
plt.close()

# 3. ROC Curves
plt.figure(figsize=(15, 10))
for i in range(len(class_names)):
    if len(np.unique(all_labels == i)) > 1:  # Only plot if we have both positive and negative samples
        fpr, tpr, _ = roc_curve(all_labels == i, all_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{class_names[i][:15]}... (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
plt.tight_layout()
plt.savefig(ANALYSIS_DIR / 'roc_curves.png', dpi=300, bbox_inches='tight')
plt.close()

# 4. Classification Report
report = classification_report(all_labels, all_preds, target_names=class_names)
print("\nClassification Report:")
print(report)

with open(ANALYSIS_DIR / 'classification_report.txt', 'w') as f:
    f.write(report)

# 5. Overall Metrics
accuracy = (all_preds == all_labels).mean()
print(f"\nOverall Validation Accuracy: {accuracy:.4f}")

# Save metrics
metrics = {
    'overall_accuracy': float(accuracy),
    'per_class_accuracy': {class_names[i]: float(class_accuracy[i]) for i in range(len(class_names))},
    'number_of_validation_samples': len(val_dataset),
    'number_of_classes': len(class_names)
}

with open(ANALYSIS_DIR / 'validation_metrics.json', 'w') as f:
    json.dump(metrics, f, indent=4)

print(f"\nAll visualizations and metrics have been saved to {ANALYSIS_DIR}")
# Out:
# Initializing model...
# <ipython-input-6-8a732a0850b0>:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(MODEL_PATH, map_location='cuda' if torch.cuda.is_available() else 'cpu')
# Model loaded and moved to cuda
#
# Loading validation dataset...
# Number of classes: 38
# Using validation directory: /content/drive/MyDrive/SpeciesDetectionAI/dataset/splits/val
# Found 37 images for species banded civet
# Found 1 images for species banded linsang
# Found 1 images for species bay cat
# Found 63 images for species bearded pig
# Found 1 images for species binturong
# Found 1 images for species bird sp
# Found 20 images for species bulwer's pheasant
# Found 68 images for species great argus pheasant
# Found 1 images for species ground tufted squirrel
# Found 40 images for species human
# Found 21 images for species leopard cat
# Found 58 images for species long-tailed macaque
# Found 4 images for species long-tailed porcupine
# Found 44 images for species malayan civet
# Found 51 images for species malayan porcupine
# Found 1 images for species marbled cat
# Found 1 images for species masked palm civet
# Found 25 images for species mongoose sp
# Found 2 images for species monitor lizard
# Found 9 images for species mouse sp
# Found 40 images for species mousedeer sp
# Found 46 images for species muntjac sp
# Found 1 images for species otter civet
# Found 2 images for species pangolin
# Found 91 images for species pig-tailed macaque
# Found 1 images for species pigeon sp
# Found 15 images for species rat sp
# Found 1 images for species roughneck monitor lizard
# Found 11 images for species roulroul
# Found 80 images for species sambar deer
# Found 2 images for species small-toothed palm civet
# Found 3 images for species squirrel sp
# Found 62 images for species sun bear
# Found 47 images for species thick-spined porcupine
# Found 25 images for species treeshrew sp
# Found 1 images for species tufted squirrel
# Found 2 images for species white fronted langur
# Found 2 images for species yellow-throated marten
#
# Total images found: 881
#
# Running predictions...
# Evaluating:   0%|          | 0/28 [00:00<?, ?it/s]
# Generating visualizations...
#
# Classification Report:
#                           precision    recall  f1-score   support
#
#             banded civet       0.97      1.00      0.99        37
#           banded linsang       1.00      1.00      1.00         1
#                  bay cat       1.00      1.00      1.00         1
#              bearded pig       1.00      0.98      0.99        63
#                binturong       1.00      1.00      1.00         1
#                  bird sp       1.00      1.00      1.00         1
#        bulwer's pheasant       1.00      1.00      1.00        20
#     great argus pheasant       1.00      0.99      0.99        68
#   ground tufted squirrel       1.00      1.00      1.00         1
#                    human       1.00      1.00      1.00        40
#              leopard cat       1.00      1.00      1.00        21
#      long-tailed macaque       0.97      1.00      0.98        58
#    long-tailed porcupine       0.80      1.00      0.89         4
#            malayan civet       1.00      0.98      0.99        44
#        malayan porcupine       1.00      0.96      0.98        51
#              marbled cat       1.00      1.00      1.00         1
#        masked palm civet       1.00      1.00      1.00         1
#              mongoose sp       1.00      1.00      1.00        25
#           monitor lizard       1.00      1.00      1.00         2
#                 mouse sp       0.90      1.00      0.95         9
#             mousedeer sp       1.00      1.00      1.00        40
#               muntjac sp       1.00      1.00      1.00        46
#              otter civet       1.00      1.00      1.00         1
#                 pangolin       1.00      1.00      1.00         2
#       pig-tailed macaque       1.00      0.99      0.99        91
#                pigeon sp       1.00      1.00      1.00         1
#                   rat sp       1.00      1.00      1.00        15
# roughneck monitor lizard       1.00      1.00      1.00         1
#                 roulroul       1.00      1.00      1.00        11
#              sambar deer       0.99      1.00      0.99        80
# small-toothed palm civet       1.00      1.00      1.00         2
#              squirrel sp       1.00      1.00      1.00         3
#                 sun bear       1.00      1.00      1.00        62
#   thick-spined porcupine       0.98      0.98      0.98        47
#             treeshrew sp       1.00      1.00      1.00        25
#          tufted squirrel       1.00      1.00      1.00         1
#     white fronted langur       1.00      1.00      1.00         2
#   yellow-throated marten       1.00      1.00      1.00         2
#
#                 accuracy                           0.99       881
#                macro avg       0.99      1.00      0.99       881
#             weighted avg       0.99      0.99      0.99       881
#
#
# Overall Validation Accuracy: 0.9921
#
# All visualizations and metrics have been saved to /content/drive/MyDrive/SpeciesDetectionAI/outputs/analysis
